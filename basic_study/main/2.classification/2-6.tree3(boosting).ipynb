# %% [markdown]
# # Boosting
#
# - bagging이 여러개의 분류기를 만들었다면 boosting은 약한 분류기를 훈련시켜 강하게 만듬
# - 성능은 좋을 수 있으나 일반적으로 bagging(RF)에 비해 많이 오래걸림
# - adaboost와 gbm이 대표적이며 gbm을 중점으로 다룰 예정
#     - adaboost는 반복해서 분류기를 훈련하면서 가중치를 두어 최종 결과를 만듬
#     - gbm은 그 과정을 경사하강법(gradient descent)를 사용함
#
#
# - parameters: tree에서 계승 하며 훈련을 위한 추가 파라미터가 존재
#     - boosting기법은 파라미터의 최적화가 매우 중요함
#     - 여러 파라미터를 어떻게 튜닝할지도 함께 알아보자
# - 자체 함수도 있지만 많이 사용하는 xgboost와 lightgbm을 알아보자
#
# # XGBoost
# - 시간을 단축하기 위해 병렬 처리를 가능하게 해주는 패키지
# - gpu연산도 손쉽게 가능한 것이 장점
# - (파이썬 래퍼의 경우)자체 데이터셋을 사용(DMatrix) => 최적화가 잘 되어있다고 함
#     - sklearn 래퍼를 사용할 것이므로 알아두기만 하자
# - parameters:
#     - booster: 사용할 알고리즘 종류
#         - gbtree, dart, gblinear
#     - nthread: 병렬연산 관련
#     - ----------------
#     - n_estimators: 여러번 훈련시키는 그 여러번에 해당
#     - learning_rate: 오차를 얼마큼 반영시켜 답을 찾을 지
#     - max_depth: 트리 최대 깊이
#     - subsample: 데이터를 샘플링하는 비율(과적합방지)
#     - colsample_bytree: 변수를 샘플링하는 비율(과적합방지)
#     - gamma: 트리를 나누기 위한 손실 감소 기준
#     - reg_lamda: L2 규제
#     - reg_alpha: L1 규제
#     - -----------
#     - objective: 학습규칙
#         - reg:linear, munlti:softmax 등
#     - eval_metric: 모형에 손실을 계산하기 위한 평가 규칙
#         - rmse, mae, error, auc 등
#
# + ++ early_stopping_rounds: 조기 중단 시켜 시간을 단축시킬 수 있는 기능을 줌

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

data = pd.read_csv('../1.clustering/titanic.csv')

target = data['Survived']
data = data.drop(['PassengerId', 'Survived'], axis=1)

def sex(a):
    if a == 'male':
        return 0
    else:
        return 1
    
def emb(a):
    if a == 'S':
        return 0
    elif a == 'Q':
        return 1
    else:
        return 2
    
data['Sex'] = data['Sex'].map(sex)
data['Embarked'] = data['Embarked'].map(emb)

train_X, test_X, train_y, test_y = train_test_split(data, target, test_size=0.3, random_state=2019, shuffle=True)

# %%
from xgboost import XGBClassifier

params= {
    'booster': 'gbtree',
    'tree_method': 'gpu_hist',
    'n_estimators': 400,
    'learning_rate': 0.1,
    'max_depth': 6,
    'subsample': 0.7,
    'colsample_bytree': 0.7,
#     'reg_alpha': 1,
#     'reg_lambda': 2
    'random_state': 0
}

# %%
xgb_clf = XGBClassifier(**params).fit(train_X, train_y, early_stopping_rounds=100, eval_metric='error', eval_set=[(test_X, test_y)])
print(accuracy_score(test_y, xgb_clf.predict(test_X)))
## eval_metric 설정으로 달라지는 학습결과 보기
# Out:
# [0]	validation_0-error:0.257009
# Will train until validation_0-error hasn't improved in 100 rounds.
# [1]	validation_0-error:0.224299
# [2]	validation_0-error:0.252336
# [3]	validation_0-error:0.205607
# [4]	validation_0-error:0.219626
# [5]	validation_0-error:0.224299
# [6]	validation_0-error:0.191589
# [7]	validation_0-error:0.21028
# [8]	validation_0-error:0.186916
# [9]	validation_0-error:0.182243
# [10]	validation_0-error:0.200935
# [11]	validation_0-error:0.205607
# [12]	validation_0-error:0.196262
# [13]	validation_0-error:0.205607
# [14]	validation_0-error:0.186916
# [15]	validation_0-error:0.205607
# [16]	validation_0-error:0.200935
# [17]	validation_0-error:0.200935
# [18]	validation_0-error:0.196262
# [19]	validation_0-error:0.200935
# [20]	validation_0-error:0.191589
# [21]	validation_0-error:0.191589
# [22]	validation_0-error:0.196262
# [23]	validation_0-error:0.191589
# [24]	validation_0-error:0.205607
# [25]	validation_0-error:0.219626
# [26]	validation_0-error:0.196262
# [27]	validation_0-error:0.196262
# [28]	validation_0-error:0.186916
# [29]	validation_0-error:0.191589
# [30]	validation_0-error:0.191589
# [31]	validation_0-error:0.191589
# [32]	validation_0-error:0.186916
# [33]	validation_0-error:0.182243
# [34]	validation_0-error:0.17757
# [35]	validation_0-error:0.17757
# [36]	validation_0-error:0.172897
# [37]	validation_0-error:0.17757
# [38]	validation_0-error:0.186916
# [39]	validation_0-error:0.191589
# [40]	validation_0-error:0.17757
# [41]	validation_0-error:0.191589
# [42]	validation_0-error:0.191589
# [43]	validation_0-error:0.191589
# [44]	validation_0-error:0.196262
# [45]	validation_0-error:0.200935
# [46]	validation_0-error:0.200935
# [47]	validation_0-error:0.196262
# [48]	validation_0-error:0.196262
# [49]	validation_0-error:0.200935
# [50]	validation_0-error:0.205607
# [51]	validation_0-error:0.205607
# [52]	validation_0-error:0.205607
# [53]	validation_0-error:0.205607
# [54]	validation_0-error:0.205607
# [55]	validation_0-error:0.214953
# [56]	validation_0-error:0.214953
# [57]	validation_0-error:0.21028
# [58]	validation_0-error:0.219626
# [59]	validation_0-error:0.214953
# [60]	validation_0-error:0.219626
# [61]	validation_0-error:0.21028
# [62]	validation_0-error:0.214953
# [63]	validation_0-error:0.214953
# [64]	validation_0-error:0.214953
# [65]	validation_0-error:0.214953
# [66]	validation_0-error:0.219626
# [67]	validation_0-error:0.21028
# [68]	validation_0-error:0.219626
# [69]	validation_0-error:0.219626
# [70]	validation_0-error:0.224299
# [71]	validation_0-error:0.214953
# [72]	validation_0-error:0.224299
# [73]	validation_0-error:0.224299
# [74]	validation_0-error:0.224299
# [75]	validation_0-error:0.228972
# [76]	validation_0-error:0.224299
# [77]	validation_0-error:0.224299
# [78]	validation_0-error:0.224299
# [79]	validation_0-error:0.228972
# [80]	validation_0-error:0.224299
# [81]	validation_0-error:0.214953
# [82]	validation_0-error:0.219626
# [83]	validation_0-error:0.21028
# [84]	validation_0-error:0.219626
# [85]	validation_0-error:0.214953
# [86]	validation_0-error:0.214953
# [87]	validation_0-error:0.214953
# [88]	validation_0-error:0.219626
# [89]	validation_0-error:0.224299
# [90]	validation_0-error:0.214953
# [91]	validation_0-error:0.214953
# [92]	validation_0-error:0.219626
# [93]	validation_0-error:0.214953
# [94]	validation_0-error:0.219626
# [95]	validation_0-error:0.214953
# [96]	validation_0-error:0.214953
# [97]	validation_0-error:0.21028
# [98]	validation_0-error:0.21028
# [99]	validation_0-error:0.21028
# [100]	validation_0-error:0.21028
# [101]	validation_0-error:0.214953
# [102]	validation_0-error:0.21028
# [103]	validation_0-error:0.21028
# [104]	validation_0-error:0.214953
# [105]	validation_0-error:0.21028
# [106]	validation_0-error:0.205607
# [107]	validation_0-error:0.214953
# [108]	validation_0-error:0.200935
# [109]	validation_0-error:0.21028
# [110]	validation_0-error:0.214953
# [111]	validation_0-error:0.214953
# [112]	validation_0-error:0.214953
# [113]	validation_0-error:0.214953
# [114]	validation_0-error:0.214953
# [115]	validation_0-error:0.214953
# [116]	validation_0-error:0.214953
# [117]	validation_0-error:0.214953
# [118]	validation_0-error:0.219626
# [119]	validation_0-error:0.214953
# [120]	validation_0-error:0.214953
# [121]	validation_0-error:0.214953
# [122]	validation_0-error:0.214953
# [123]	validation_0-error:0.219626
# [124]	validation_0-error:0.21028
# [125]	validation_0-error:0.214953
# [126]	validation_0-error:0.214953
# [127]	validation_0-error:0.205607
# [128]	validation_0-error:0.21028
# [129]	validation_0-error:0.214953
# [130]	validation_0-error:0.214953
# [131]	validation_0-error:0.205607
# [132]	validation_0-error:0.205607
# [133]	validation_0-error:0.205607
# [134]	validation_0-error:0.21028
# [135]	validation_0-error:0.21028
# [136]	validation_0-error:0.21028
# Stopping. Best iteration:
# [36]	validation_0-error:0.172897
#
# 0.8271028037383178

# %% [markdown]
# # LightGBM
#
# - xgboost와 양대산맥을 이루는 tree관련 패키지
# - xgboost보다 빠른 연산 시간을 보여준다고 함
# - 최신 패키지인 만큼 기능도 몇 가지 보안됨
# - 가장 큰 특징으로 leaf wise 분할 (반대는 level wise)
#     - 이로 인해 보통 트리 깊이가 더 깊어짐
# - 데이터 수가 적을 경우 과적합이 더 자주 발생한다고 함 (공식문서에서 만건 이하)
# - 파라미터는 거의 유사

# %%
from lightgbm import LGBMClassifier

params= {
    'boosting': 'gbdt',
#     'tree_method': 'gpu_hist',
    'n_estimators': 400,
    'learning_rate': 0.1,
    'max_depth': 9,
    'min_child_samples': 20, # 결정노드가 되기 위한 최소 자료 수
    'num_leaves': 31, # 트리가 가질 수 있는 최대 리프 수
    'subsample': 0.7, # bagging_fraction
    'colsample_bytree': 0.7, # feature_fraction
    'random_state': 0,
}

lgb_clf = LGBMClassifier(**params).fit(train_X, train_y, early_stopping_rounds=100,eval_set=[(test_X, test_y)], eval_metric='auc')
print(accuracy_score(test_y, lgb_clf.predict(test_X)))
# Out:
# [1]	valid_0's auc: 0.828899	valid_0's binary_logloss: 0.630457
# Training until validation scores don't improve for 100 rounds
# [2]	valid_0's auc: 0.834996	valid_0's binary_logloss: 0.602703
# [3]	valid_0's auc: 0.833149	valid_0's binary_logloss: 0.590206
# [4]	valid_0's auc: 0.843173	valid_0's binary_logloss: 0.56688
# [5]	valid_0's auc: 0.842249	valid_0's binary_logloss: 0.547903
# [6]	valid_0's auc: 0.839616	valid_0's binary_logloss: 0.533839
# [7]	valid_0's auc: 0.843727	valid_0's binary_logloss: 0.519588
# [8]	valid_0's auc: 0.840262	valid_0's binary_logloss: 0.516946
# [9]	valid_0's auc: 0.843126	valid_0's binary_logloss: 0.505515
# [10]	valid_0's auc: 0.840955	valid_0's binary_logloss: 0.504042
# [11]	valid_0's auc: 0.841787	valid_0's binary_logloss: 0.495516
# [12]	valid_0's auc: 0.846175	valid_0's binary_logloss: 0.491644
# [13]	valid_0's auc: 0.847284	valid_0's binary_logloss: 0.484786
# [14]	valid_0's auc: 0.84539	valid_0's binary_logloss: 0.479464
# [15]	valid_0's auc: 0.84539	valid_0's binary_logloss: 0.474951
# [16]	valid_0's auc: 0.845759	valid_0's binary_logloss: 0.472341
# [17]	valid_0's auc: 0.844928	valid_0's binary_logloss: 0.468121
# [18]	valid_0's auc: 0.847238	valid_0's binary_logloss: 0.46495
# [19]	valid_0's auc: 0.845759	valid_0's binary_logloss: 0.463178
# [20]	valid_0's auc: 0.845528	valid_0's binary_logloss: 0.461828
# [21]	valid_0's auc: 0.846268	valid_0's binary_logloss: 0.460387
# [22]	valid_0's auc: 0.846175	valid_0's binary_logloss: 0.45908
# [23]	valid_0's auc: 0.847746	valid_0's binary_logloss: 0.45849
# [24]	valid_0's auc: 0.846083	valid_0's binary_logloss: 0.45786
# [25]	valid_0's auc: 0.845713	valid_0's binary_logloss: 0.457946
# [26]	valid_0's auc: 0.846637	valid_0's binary_logloss: 0.456114
# [27]	valid_0's auc: 0.846637	valid_0's binary_logloss: 0.455587
# [28]	valid_0's auc: 0.847561	valid_0's binary_logloss: 0.455067
# [29]	valid_0's auc: 0.846175	valid_0's binary_logloss: 0.455256
# [30]	valid_0's auc: 0.844789	valid_0's binary_logloss: 0.456491
# [31]	valid_0's auc: 0.84442	valid_0's binary_logloss: 0.458033
# [32]	valid_0's auc: 0.844605	valid_0's binary_logloss: 0.45821
# [33]	valid_0's auc: 0.846729	valid_0's binary_logloss: 0.458394
# [34]	valid_0's auc: 0.845344	valid_0's binary_logloss: 0.459889
# [35]	valid_0's auc: 0.845713	valid_0's binary_logloss: 0.46004
# [36]	valid_0's auc: 0.846637	valid_0's binary_logloss: 0.459941
# [37]	valid_0's auc: 0.84733	valid_0's binary_logloss: 0.460031
# [38]	valid_0's auc: 0.846221	valid_0's binary_logloss: 0.461049
# [39]	valid_0's auc: 0.845667	valid_0's binary_logloss: 0.462381
# [40]	valid_0's auc: 0.845575	valid_0's binary_logloss: 0.462406
# [41]	valid_0's auc: 0.845113	valid_0's binary_logloss: 0.463297
# [42]	valid_0's auc: 0.845759	valid_0's binary_logloss: 0.463692
# [43]	valid_0's auc: 0.84696	valid_0's binary_logloss: 0.462736
# [44]	valid_0's auc: 0.84696	valid_0's binary_logloss: 0.464653
# [45]	valid_0's auc: 0.845667	valid_0's binary_logloss: 0.466087
# [46]	valid_0's auc: 0.84696	valid_0's binary_logloss: 0.464842
# [47]	valid_0's auc: 0.846129	valid_0's binary_logloss: 0.46656
# [48]	valid_0's auc: 0.844189	valid_0's binary_logloss: 0.466532
# [49]	valid_0's auc: 0.842249	valid_0's binary_logloss: 0.469472
# [50]	valid_0's auc: 0.841602	valid_0's binary_logloss: 0.470714
# [51]	valid_0's auc: 0.840771	valid_0's binary_logloss: 0.472997
# [52]	valid_0's auc: 0.840586	valid_0's binary_logloss: 0.473382
# [53]	valid_0's auc: 0.840586	valid_0's binary_logloss: 0.475024
# [54]	valid_0's auc: 0.841694	valid_0's binary_logloss: 0.475634
# [55]	valid_0's auc: 0.840309	valid_0's binary_logloss: 0.476558
# [56]	valid_0's auc: 0.840586	valid_0's binary_logloss: 0.47572
# [57]	valid_0's auc: 0.840031	valid_0's binary_logloss: 0.476894
# [58]	valid_0's auc: 0.840031	valid_0's binary_logloss: 0.476754
# [59]	valid_0's auc: 0.840401	valid_0's binary_logloss: 0.478571
# [60]	valid_0's auc: 0.839754	valid_0's binary_logloss: 0.478834
# [61]	valid_0's auc: 0.838923	valid_0's binary_logloss: 0.480146
# [62]	valid_0's auc: 0.838461	valid_0's binary_logloss: 0.48069
# [63]	valid_0's auc: 0.836983	valid_0's binary_logloss: 0.48339
# [64]	valid_0's auc: 0.838553	valid_0's binary_logloss: 0.482619
# [65]	valid_0's auc: 0.839754	valid_0's binary_logloss: 0.481694
# [66]	valid_0's auc: 0.839754	valid_0's binary_logloss: 0.483713
# [67]	valid_0's auc: 0.839847	valid_0's binary_logloss: 0.484307
# [68]	valid_0's auc: 0.837352	valid_0's binary_logloss: 0.488236
# [69]	valid_0's auc: 0.836705	valid_0's binary_logloss: 0.488492
# [70]	valid_0's auc: 0.835966	valid_0's binary_logloss: 0.488707
# [71]	valid_0's auc: 0.835689	valid_0's binary_logloss: 0.490393
# [72]	valid_0's auc: 0.834488	valid_0's binary_logloss: 0.49242
# [73]	valid_0's auc: 0.835042	valid_0's binary_logloss: 0.49323
# [74]	valid_0's auc: 0.834581	valid_0's binary_logloss: 0.493869
# [75]	valid_0's auc: 0.834673	valid_0's binary_logloss: 0.493428
# [76]	valid_0's auc: 0.83338	valid_0's binary_logloss: 0.494815
# [77]	valid_0's auc: 0.833195	valid_0's binary_logloss: 0.496623
# [78]	valid_0's auc: 0.833287	valid_0's binary_logloss: 0.496631
# [79]	valid_0's auc: 0.833195	valid_0's binary_logloss: 0.497119
# [80]	valid_0's auc: 0.83264	valid_0's binary_logloss: 0.498719
# [81]	valid_0's auc: 0.834211	valid_0's binary_logloss: 0.499075
# [82]	valid_0's auc: 0.834211	valid_0's binary_logloss: 0.499429
# [83]	valid_0's auc: 0.832825	valid_0's binary_logloss: 0.501292
# [84]	valid_0's auc: 0.832178	valid_0's binary_logloss: 0.501618
# [85]	valid_0's auc: 0.833287	valid_0's binary_logloss: 0.501506
# [86]	valid_0's auc: 0.833195	valid_0's binary_logloss: 0.50243
# [87]	valid_0's auc: 0.833102	valid_0's binary_logloss: 0.503377
# [88]	valid_0's auc: 0.831255	valid_0's binary_logloss: 0.508337
# [89]	valid_0's auc: 0.830331	valid_0's binary_logloss: 0.510513
# [90]	valid_0's auc: 0.830423	valid_0's binary_logloss: 0.511339
# [91]	valid_0's auc: 0.830331	valid_0's binary_logloss: 0.512377
# [92]	valid_0's auc: 0.830516	valid_0's binary_logloss: 0.512795
# [93]	valid_0's auc: 0.830146	valid_0's binary_logloss: 0.513846
# [94]	valid_0's auc: 0.8307	valid_0's binary_logloss: 0.513825
# [95]	valid_0's auc: 0.829961	valid_0's binary_logloss: 0.51592
# [96]	valid_0's auc: 0.8307	valid_0's binary_logloss: 0.515021
# [97]	valid_0's auc: 0.831717	valid_0's binary_logloss: 0.515474
# [98]	valid_0's auc: 0.830608	valid_0's binary_logloss: 0.517965
# [99]	valid_0's auc: 0.82876	valid_0's binary_logloss: 0.51976
# [100]	valid_0's auc: 0.827744	valid_0's binary_logloss: 0.522536
# [101]	valid_0's auc: 0.828668	valid_0's binary_logloss: 0.521602
# [102]	valid_0's auc: 0.827929	valid_0's binary_logloss: 0.522666
# [103]	valid_0's auc: 0.828483	valid_0's binary_logloss: 0.523404
# [104]	valid_0's auc: 0.82913	valid_0's binary_logloss: 0.523951
# [105]	valid_0's auc: 0.827929	valid_0's binary_logloss: 0.524543
# [106]	valid_0's auc: 0.828298	valid_0's binary_logloss: 0.525475
# [107]	valid_0's auc: 0.827929	valid_0's binary_logloss: 0.527868
# [108]	valid_0's auc: 0.82876	valid_0's binary_logloss: 0.525862
# [109]	valid_0's auc: 0.827744	valid_0's binary_logloss: 0.528292
# [110]	valid_0's auc: 0.826912	valid_0's binary_logloss: 0.52984
# [111]	valid_0's auc: 0.825989	valid_0's binary_logloss: 0.531923
# [112]	valid_0's auc: 0.825896	valid_0's binary_logloss: 0.533534
# [113]	valid_0's auc: 0.826543	valid_0's binary_logloss: 0.53352
# [114]	valid_0's auc: 0.825989	valid_0's binary_logloss: 0.534377
# [115]	valid_0's auc: 0.823864	valid_0's binary_logloss: 0.537765
# [116]	valid_0's auc: 0.825157	valid_0's binary_logloss: 0.53743
# [117]	valid_0's auc: 0.825989	valid_0's binary_logloss: 0.538817
# [118]	valid_0's auc: 0.825527	valid_0's binary_logloss: 0.541733
# [119]	valid_0's auc: 0.825711	valid_0's binary_logloss: 0.543497
# [120]	valid_0's auc: 0.825619	valid_0's binary_logloss: 0.542432
# [121]	valid_0's auc: 0.825065	valid_0's binary_logloss: 0.543857
# [122]	valid_0's auc: 0.825434	valid_0's binary_logloss: 0.544101
# [123]	valid_0's auc: 0.825342	valid_0's binary_logloss: 0.545921
# Early stopping, best iteration is:
# [23]	valid_0's auc: 0.847746	valid_0's binary_logloss: 0.45849
# 0.8084112149532711

# %%
## customized eval metrics
def custom_eval_metric(y_true, y_hat):
    ## y_true는 실제 값, y_hat은 확률로 넘어와서 비교해야 함
    y_hat = np.where(y_hat < 0.5, 0, 1)
    return 'custom', accuracy_score(y_true, y_hat), True

params= {
    'boosting': 'gbdt',
#     'tree_method': 'gpu_hist',
    'n_estimators': 400,
    'learning_rate': 0.1,
    'max_depth': 9,
    'min_child_samples': 20, # 결정노드가 되기 위한 최소 자료 수
    'num_leaves': 31, # 트리가 가질 수 있는 최대 리프 수
    'subsample': 0.9, # bagging_fraction
    'colsample_bytree': 0.9, # feature_fraction
    'random_state': 0,
    'metric': 'auc'
}

lgb_clf = LGBMClassifier(**params).fit(train_X, train_y, early_stopping_rounds=100,eval_set=[(test_X, test_y)], eval_metric=custom_eval_metric)
print(accuracy_score(test_y, lgb_clf.predict(test_X)))
# Out:
# [1]	valid_0's auc: 0.821508	valid_0's custom: 0.616822
# Training until validation scores don't improve for 100 rounds
# [2]	valid_0's auc: 0.826173	valid_0's custom: 0.742991
# [3]	valid_0's auc: 0.834303	valid_0's custom: 0.738318
# [4]	valid_0's auc: 0.840909	valid_0's custom: 0.775701
# [5]	valid_0's auc: 0.843542	valid_0's custom: 0.780374
# [6]	valid_0's auc: 0.844605	valid_0's custom: 0.785047
# [7]	valid_0's auc: 0.843865	valid_0's custom: 0.775701
# [8]	valid_0's auc: 0.841925	valid_0's custom: 0.803738
# [9]	valid_0's auc: 0.842757	valid_0's custom: 0.808411
# [10]	valid_0's auc: 0.842849	valid_0's custom: 0.803738
# [11]	valid_0's auc: 0.845067	valid_0's custom: 0.808411
# [12]	valid_0's auc: 0.84696	valid_0's custom: 0.813084
# [13]	valid_0's auc: 0.845297	valid_0's custom: 0.799065
# [14]	valid_0's auc: 0.846499	valid_0's custom: 0.799065
# [15]	valid_0's auc: 0.843912	valid_0's custom: 0.794393
# [16]	valid_0's auc: 0.845621	valid_0's custom: 0.794393
# [17]	valid_0's auc: 0.846637	valid_0's custom: 0.799065
# [18]	valid_0's auc: 0.846637	valid_0's custom: 0.78972
# [19]	valid_0's auc: 0.847469	valid_0's custom: 0.794393
# [20]	valid_0's auc: 0.847007	valid_0's custom: 0.794393
# [21]	valid_0's auc: 0.846175	valid_0's custom: 0.78972
# [22]	valid_0's auc: 0.843819	valid_0's custom: 0.78972
# [23]	valid_0's auc: 0.842295	valid_0's custom: 0.78972
# [24]	valid_0's auc: 0.841694	valid_0's custom: 0.78972
# [25]	valid_0's auc: 0.842433	valid_0's custom: 0.794393
# [26]	valid_0's auc: 0.841001	valid_0's custom: 0.794393
# [27]	valid_0's auc: 0.840355	valid_0's custom: 0.794393
# [28]	valid_0's auc: 0.839985	valid_0's custom: 0.78972
# [29]	valid_0's auc: 0.838368	valid_0's custom: 0.780374
# [30]	valid_0's auc: 0.838969	valid_0's custom: 0.785047
# [31]	valid_0's auc: 0.841833	valid_0's custom: 0.799065
# [32]	valid_0's auc: 0.840909	valid_0's custom: 0.799065
# [33]	valid_0's auc: 0.842018	valid_0's custom: 0.799065
# [34]	valid_0's auc: 0.84248	valid_0's custom: 0.78972
# [35]	valid_0's auc: 0.84211	valid_0's custom: 0.794393
# [36]	valid_0's auc: 0.84017	valid_0's custom: 0.78972
# [37]	valid_0's auc: 0.837953	valid_0's custom: 0.780374
# [38]	valid_0's auc: 0.83726	valid_0's custom: 0.780374
# [39]	valid_0's auc: 0.838738	valid_0's custom: 0.78972
# [40]	valid_0's auc: 0.835966	valid_0's custom: 0.78972
# [41]	valid_0's auc: 0.835689	valid_0's custom: 0.78972
# [42]	valid_0's auc: 0.838276	valid_0's custom: 0.78972
# [43]	valid_0's auc: 0.834211	valid_0's custom: 0.785047
# [44]	valid_0's auc: 0.834211	valid_0's custom: 0.785047
# [45]	valid_0's auc: 0.83264	valid_0's custom: 0.775701
# [46]	valid_0's auc: 0.834673	valid_0's custom: 0.780374
# [47]	valid_0's auc: 0.834488	valid_0's custom: 0.780374
# [48]	valid_0's auc: 0.83264	valid_0's custom: 0.780374
# [49]	valid_0's auc: 0.832271	valid_0's custom: 0.780374
# [50]	valid_0's auc: 0.833102	valid_0's custom: 0.785047
# [51]	valid_0's auc: 0.834026	valid_0's custom: 0.780374
# [52]	valid_0's auc: 0.832733	valid_0's custom: 0.78972
# [53]	valid_0's auc: 0.831439	valid_0's custom: 0.78972
# [54]	valid_0's auc: 0.831717	valid_0's custom: 0.785047
# [55]	valid_0's auc: 0.831717	valid_0's custom: 0.785047
# [56]	valid_0's auc: 0.83301	valid_0's custom: 0.794393
# [57]	valid_0's auc: 0.83338	valid_0's custom: 0.794393
# [58]	valid_0's auc: 0.833749	valid_0's custom: 0.799065
# [59]	valid_0's auc: 0.832825	valid_0's custom: 0.799065
# [60]	valid_0's auc: 0.832271	valid_0's custom: 0.78972
# [61]	valid_0's auc: 0.832363	valid_0's custom: 0.794393
# [62]	valid_0's auc: 0.832825	valid_0's custom: 0.794393
# [63]	valid_0's auc: 0.832918	valid_0's custom: 0.785047
# [64]	valid_0's auc: 0.832548	valid_0's custom: 0.78972
# [65]	valid_0's auc: 0.829684	valid_0's custom: 0.78972
# [66]	valid_0's auc: 0.829499	valid_0's custom: 0.78972
# [67]	valid_0's auc: 0.830238	valid_0's custom: 0.785047
# [68]	valid_0's auc: 0.829869	valid_0's custom: 0.780374
# [69]	valid_0's auc: 0.830238	valid_0's custom: 0.771028
# [70]	valid_0's auc: 0.830885	valid_0's custom: 0.771028
# [71]	valid_0's auc: 0.829407	valid_0's custom: 0.766355
# [72]	valid_0's auc: 0.828945	valid_0's custom: 0.766355
# [73]	valid_0's auc: 0.82913	valid_0's custom: 0.771028
# [74]	valid_0's auc: 0.828668	valid_0's custom: 0.775701
# [75]	valid_0's auc: 0.82645	valid_0's custom: 0.775701
# [76]	valid_0's auc: 0.826543	valid_0's custom: 0.771028
# [77]	valid_0's auc: 0.825619	valid_0's custom: 0.771028
# [78]	valid_0's auc: 0.825065	valid_0's custom: 0.775701
# [79]	valid_0's auc: 0.824326	valid_0's custom: 0.775701
# [80]	valid_0's auc: 0.824603	valid_0's custom: 0.780374
# [81]	valid_0's auc: 0.823125	valid_0's custom: 0.780374
# [82]	valid_0's auc: 0.824141	valid_0's custom: 0.766355
# [83]	valid_0's auc: 0.823679	valid_0's custom: 0.771028
# [84]	valid_0's auc: 0.823309	valid_0's custom: 0.761682
# [85]	valid_0's auc: 0.823217	valid_0's custom: 0.761682
# [86]	valid_0's auc: 0.823771	valid_0's custom: 0.766355
# [87]	valid_0's auc: 0.823771	valid_0's custom: 0.766355
# [88]	valid_0's auc: 0.824141	valid_0's custom: 0.766355
# [89]	valid_0's auc: 0.822108	valid_0's custom: 0.771028
# [90]	valid_0's auc: 0.821739	valid_0's custom: 0.775701
# [91]	valid_0's auc: 0.822847	valid_0's custom: 0.771028
# [92]	valid_0's auc: 0.823771	valid_0's custom: 0.771028
# [93]	valid_0's auc: 0.822847	valid_0's custom: 0.766355
# [94]	valid_0's auc: 0.821924	valid_0's custom: 0.771028
# [95]	valid_0's auc: 0.820722	valid_0's custom: 0.771028
# [96]	valid_0's auc: 0.821462	valid_0's custom: 0.771028
# [97]	valid_0's auc: 0.821554	valid_0's custom: 0.766355
# [98]	valid_0's auc: 0.821092	valid_0's custom: 0.766355
# [99]	valid_0's auc: 0.819337	valid_0's custom: 0.766355
# [100]	valid_0's auc: 0.820538	valid_0's custom: 0.757009
# [101]	valid_0's auc: 0.820722	valid_0's custom: 0.761682
# [102]	valid_0's auc: 0.819983	valid_0's custom: 0.761682
# [103]	valid_0's auc: 0.820538	valid_0's custom: 0.775701
# [104]	valid_0's auc: 0.820168	valid_0's custom: 0.771028
# [105]	valid_0's auc: 0.817858	valid_0's custom: 0.771028
# [106]	valid_0's auc: 0.817212	valid_0's custom: 0.766355
# [107]	valid_0's auc: 0.817304	valid_0's custom: 0.766355
# [108]	valid_0's auc: 0.818228	valid_0's custom: 0.761682
# [109]	valid_0's auc: 0.818875	valid_0's custom: 0.761682
# [110]	valid_0's auc: 0.819706	valid_0's custom: 0.766355
# [111]	valid_0's auc: 0.819983	valid_0's custom: 0.766355
# [112]	valid_0's auc: 0.817951	valid_0's custom: 0.761682
# Early stopping, best iteration is:
# [12]	valid_0's auc: 0.84696	valid_0's custom: 0.813084
# 0.8130841121495327
