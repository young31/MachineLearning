# %% [markdown]
# # PCA
#
# - 주로 DR(차원축소)을 목적으로 사용되며
# - rough한 모형으로 메인으로 사용하는 모형은 아님
#
#
# - 내용은 발제 참고
#
#
# - 예시 상황:
# 변수가 400개인 상황에서 모두 모형에 포함시키면 성능문제를 포함하여 몇 가지 문제가 생김
# 이 상황에서 PCA를 사용한 변수만 사용(자료의 정보는 보존하면서 사용하는 변수의 수는 줄일 수 있음)

# %%
import numpy as np
import pandas as pd
import seaborn as sns

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.datasets import load_boston
from sklearn.decomposition import PCA

std = StandardScaler()

boston = load_boston()
X = pd.DataFrame(boston.data, columns=boston.feature_names)
y = pd.DataFrame(boston.target, columns=['target'])

std_X = pd.DataFrame(std.fit_transform(X), columns=X.columns)

pca = PCA() ## n_components지정해서 볼 것 만 볼 수 있음
pca_std = pd.DataFrame(pca.fit_transform(std_X))

# %%
pca_std
# Out:
#            0         1         2         3         4         5         6   \
# 0   -2.098297  0.773113  0.342943 -0.891774  0.423070 -0.315338  0.318641
# 1   -1.457252  0.591985 -0.695199 -0.487459 -0.195876  0.264223  0.553861
# 2   -2.074598  0.599639  0.167122 -0.739204 -0.934534  0.448095  0.484560
# 3   -2.611504 -0.006871 -0.100284 -0.343721 -1.104956  0.664649  0.622641
# 4   -2.458185  0.097712 -0.075348 -0.427907 -1.065924  0.617047  0.705086
# 5   -2.214852 -0.009487 -0.672381 -0.175910 -0.627188  0.571419  0.651183
# 6   -1.358881  0.349872 -0.371999 -0.398134  1.073148 -0.458869  0.019765
# 7   -0.842045  0.577800 -0.518540 -0.537758  1.379688 -0.579258  0.224832
# 8   -0.179928  0.342518 -1.349639 -0.245920  2.350304 -0.625062  0.314740
# 9   -1.074184  0.316201 -0.558469 -0.379932  1.430531 -0.455876  0.105209
# 10  -0.909412  0.507752 -0.385242 -0.562782  1.362784 -0.526110  0.236261
# 11  -1.243655  0.413099 -0.435413 -0.419479  1.157666 -0.511729  0.067720
# 12  -1.462897 -0.012019 -0.561960 -0.165697  1.326617 -0.379775 -0.063316
# 13  -0.735774 -0.127295 -1.285177  0.191672 -0.857374  0.449916  0.175080
# 14  -0.360018  0.131280 -1.188315 -0.045340 -0.769435  0.535279  0.306373
# 15  -0.720059 -0.181344 -1.377934  0.248932 -0.784492  0.461163  0.154417
# 16  -1.100777 -0.480514 -1.163537  0.346499 -0.928786  0.619505  0.060194
# 17  -0.150713  0.077812 -1.454430  0.049981 -0.496911  0.435275  0.367450
# 18  -0.350567 -0.684915 -1.433260  0.287714 -0.017350  1.383011  0.045521
# 19  -0.303610  0.011520 -1.547024  0.158228 -0.571082  0.428819  0.272557
# 20   0.527793  0.136796 -2.000003  0.114926  0.138883  0.383225  0.531484
# 21  -0.070130  0.217834 -1.460129 -0.008913 -0.556600  0.364916  0.408592
# 22   0.129156  0.235629 -1.497568 -0.040482 -0.406024  0.288393  0.534213
# 479  0.305029  0.010074  0.118887 -0.167356 -0.382432 -0.090567
# 480  0.643127 -0.226972 -0.307230 -0.330624 -0.598044 -0.155788
# 481  0.370664 -0.129602 -0.223941 -0.541558 -0.607615 -0.146694
# 482  0.220167 -0.099590 -0.335239 -0.605981 -0.545453 -0.132555
# 483  1.314470 -0.330587 -0.357467 -0.166171 -0.428061 -0.176336
# 484  1.106174 -0.390187 -0.494948  0.100788 -0.123580 -0.140242
# 485  0.858046 -0.297662 -0.442390 -0.235359 -0.053255 -0.131053
# 486  0.154001 -0.406970 -0.294728 -0.415988 -0.333202 -0.152614
# 487  1.037348 -0.255790 -0.177362  0.008372 -0.289405 -0.142742
# 488  0.117990  1.315303 -0.382953 -0.439290 -0.725446  1.087241
# 489 -0.327455  1.168276 -0.724354 -0.298475 -0.765805  1.100448
# 490 -0.513343  0.999284 -0.990037 -0.128622 -0.788241  1.100374
# 491 -0.262460  1.334116 -0.628912 -0.514532 -0.650092  1.112846
# 492  0.330926  1.479244 -0.455701 -0.522868 -0.523222  1.115250
# 493  0.673516 -0.021879  0.341769  0.706653  0.108297  0.259115
# 494  0.723051 -0.019562 -0.072705  0.968126  0.255214  0.294939
# 495  0.872798 -0.145260 -0.461385  1.189254  0.409317  0.306983
# 496 -0.147873 -0.365616 -0.022025  0.582000  0.046145  0.240889
# 497  0.126135 -0.147373  0.285084  0.351496  0.114242  0.245227
# 498  0.232304 -0.052642  0.217075  0.570492  0.103886  0.267108
# 499  0.136412 -0.163336  0.417684  0.489036 -0.041890  0.233927
# 500 -0.168378 -0.132217  0.271914  0.360335  0.024427  0.251861
# 501 -0.249896  0.877036  0.183086  0.493590  0.450386  0.078978
# 502 -0.146502  0.853628  0.631847  0.375688  0.252082  0.037162
# 503 -0.638660  0.981032  0.589670  0.115656  0.281964  0.062474
# 504 -0.579344  0.936755  0.594610  0.087012  0.301701  0.054370
# 505 -0.133382  0.854689  0.823404  0.184321  0.232733  0.019709
#
# [506 rows x 13 columns]

# %%
pca_vars = []
for idx in pca_std:
    pca_vars.append(np.var(pca_std[idx]))
    
cum_vars = pca_vars.copy()
cum_vars[0] /= 13
for i in range(1, len(pca_vars)):
    cum_vars[i] /= 13
    cum_vars[i] += cum_vars[i-1]

# %%
sns.pointplot(x = list(range(13)),y=cum_vars)

# %%
# self coding
## PCA를 구하는 핵심은 sigma 찾기

# %%
import gc 
gc.collect()
# Out:
# 45

# %%
# 공식구현
n = len(X)
o = np.ones([n,n])

s = std_X.T @  (np.eye(n) - o/n) @ std_X
s /= (n-1)

# %%
# # ## 위 방법을 모르는 경우
# # # 1. 평균 벡터를 만든다
# # # 2. 삼중 for문을 돌면서 값을 구한다.

# # # 카카오 인턴 예시 코드
for i in range(1, len(r_bar)):
    temp_total = sum(mat[i])
    temp_no_r = mat[i].count(0) - 1
    temp = (temp_total / (n_i - temp_no_r))
    r_bar[i] = round((temp_total / (n_i - temp_no_r)), 3)

for i in range(1, n_u + 1):
    for j in range(1, n_u + 1):
        if i != j:
            f1 = 0
            f2 = 0
            f3 = 0
            for k in range(1, n_i + 1):
                if mat[i][k] != 0 and mat[j][k] != 0:
                    f1 += (mat[i][k] - r_bar[i]) * (mat[j][k] - r_bar[j])
                    f2 += (mat[i][k] - r_bar[i]) ** 2
                    f3 += (mat[j][k] - r_bar[j]) ** 2

# %%
s
# Out:
#              CRIM        ZN     INDUS      CHAS       NOX        RM       AGE  \
# CRIM     1.001980 -0.200866  0.407389 -0.056002  0.421805 -0.219681  0.353433
# ZN      -0.200866  1.001980 -0.534885 -0.042781 -0.517627  0.312608 -0.570665
# INDUS    0.407389 -0.534885  1.001980  0.063063  0.765164 -0.392451  0.646055
# CHAS    -0.056002 -0.042781  0.063063  1.001980  0.091383  0.091432  0.086689
# NOX      0.421805 -0.517627  0.765164  0.091383  1.001980 -0.302787  0.732919
# RM      -0.219681  0.312608 -0.392451  0.091432 -0.302787  1.001980 -0.240741
# AGE      0.353433 -0.570665  0.646055  0.086689  0.732919 -0.240741  1.001980
# DIS     -0.380422  0.665724 -0.709429 -0.099372 -0.770753  0.205653 -0.749361
# RAD      0.626744 -0.312566  0.596308 -0.007383  0.612651 -0.210262  0.456925
# TAX      0.583918 -0.315186  0.722187 -0.035657  0.669346 -0.292626  0.507458
# PTRATIO  0.290520 -0.392454  0.384006 -0.121756  0.189307 -0.356205  0.262033
# B       -0.385826  0.175868 -0.357683  0.048885 -0.380803  0.128322 -0.274076
# LSTAT    0.456524 -0.413812  0.604995 -0.054036  0.592049 -0.615024  0.603531
#
#               DIS       RAD       TAX   PTRATIO         B     LSTAT
# CRIM    -0.380422  0.626744  0.583918  0.290520 -0.385826  0.456524
# ZN       0.665724 -0.312566 -0.315186 -0.392454  0.175868 -0.413812
# INDUS   -0.709429  0.596308  0.722187  0.384006 -0.357683  0.604995
# CHAS    -0.099372 -0.007383 -0.035657 -0.121756  0.048885 -0.054036
# NOX     -0.770753  0.612651  0.669346  0.189307 -0.380803  0.592049
# RM       0.205653 -0.210262 -0.292626 -0.356205  0.128322 -0.615024
# AGE     -0.749361  0.456925  0.507458  0.262033 -0.274076  0.603531
# DIS      1.001980 -0.495567 -0.535490 -0.232931  0.292089 -0.497980
# RAD     -0.495567  1.001980  0.912031  0.465661 -0.445293  0.489644
# TAX     -0.535490  0.912031  1.001980  0.461766 -0.442683  0.545071
# PTRATIO -0.232931  0.465661  0.461766  1.001980 -0.177735  0.374785
# B        0.292089 -0.445293 -0.442683 -0.177735  1.001980 -0.366812
# LSTAT   -0.497980  0.489644  0.545071  0.374785 -0.366812  1.001980

# %%
# 고유값
values, vectors = np.linalg.eig(s)

# %%
values
# Out:
# array([6.1389812 , 1.43611329, 1.2450773 , 0.85927328, 0.83646904,
#        0.65870897, 0.5364162 , 0.39688167, 0.06363502, 0.27749173,
#        0.16963823, 0.18638271, 0.22067394])

# %%
# 고유값은 독립확인
vectors[0].T @ vectors[1]
# Out:
# -6.106226635438361e-16

# %%
vectors[:,0]
# Out:
# array([-0.2509514 ,  0.25631454, -0.34667207, -0.00504243, -0.34285231,
#         0.18924257, -0.3136706 ,  0.32154387, -0.31979277, -0.33846915,
#        -0.20494226,  0.20297261, -0.30975984])

# %%
# 직접구한 값
vectors[:,0] @ std_X.T
# Out:
# 0      2.098297
# 1      1.457252
# 2      2.074598
# 3      2.611504
# 4      2.458185
# 5      2.214852
# 6      1.358881
# 7      0.842045
# 8      0.179928
# 9      1.074184
# 10     0.909412
# 11     1.243655
# 12     1.462897
# 13     0.735774
# 14     0.360018
# 15     0.720059
# 16     1.100777
# 17     0.150713
# 18     0.350567
# 19     0.303610
# 20    -0.527793
# 21     0.070130
# 22    -0.129156
# 23    -0.340847
# 24    -0.036650
# 25    -0.236241
# 26     0.047125
# 27    -0.180430
# 28     0.259457
# 29     0.365687
#          ...
# 476   -2.529761
# 477   -3.591423
# 478   -2.830655
# 479   -2.653344
# 480   -1.540291
# 481   -1.406124
# 482   -1.297696
# 483   -1.201685
# 484   -1.561729
# 485   -1.391626
# 486   -2.065304
# 487   -1.716761
# 488   -2.527696
# 489   -2.982107
# 490   -3.360682
# 491   -2.456100
# 492   -2.028589
# 493   -0.036893
# 494    0.077603
# 495    0.047026
# 496   -0.669273
# 497   -0.214016
# 498   -0.116065
# 499   -0.425641
# 500   -0.321704
# 501    0.314968
# 502    0.110513
# 503    0.312360
# 504    0.270519
# 505    0.125803
# Length: 506, dtype: float64

# %%
# 라이브러리써서 구한 값 일치
pca_std[0]
# Out:
# 0     -2.098297
# 1     -1.457252
# 2     -2.074598
# 3     -2.611504
# 4     -2.458185
# 5     -2.214852
# 6     -1.358881
# 7     -0.842045
# 8     -0.179928
# 9     -1.074184
# 10    -0.909412
# 11    -1.243655
# 12    -1.462897
# 13    -0.735774
# 14    -0.360018
# 15    -0.720059
# 16    -1.100777
# 17    -0.150713
# 18    -0.350567
# 19    -0.303610
# 20     0.527793
# 21    -0.070130
# 22     0.129156
# 23     0.340847
# 24     0.036650
# 25     0.236241
# 26    -0.047125
# 27     0.180430
# 28    -0.259457
# 29    -0.365687
#          ...
# 476    2.529761
# 477    3.591423
# 478    2.830655
# 479    2.653344
# 480    1.540291
# 481    1.406124
# 482    1.297696
# 483    1.201685
# 484    1.561729
# 485    1.391626
# 486    2.065304
# 487    1.716761
# 488    2.527696
# 489    2.982107
# 490    3.360682
# 491    2.456100
# 492    2.028589
# 493    0.036893
# 494   -0.077603
# 495   -0.047026
# 496    0.669273
# 497    0.214016
# 498    0.116065
# 499    0.425641
# 500    0.321704
# 501   -0.314968
# 502   -0.110513
# 503   -0.312360
# 504   -0.270519
# 505   -0.125803
# Name: 0, Length: 506, dtype: float64
