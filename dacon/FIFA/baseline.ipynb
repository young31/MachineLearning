# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

import os
import gc
import warnings

warnings.filterwarnings('ignore')

# %%
from sklearn.feature_selection import SelectFromModel
from sklearn.preprocessing import LabelEncoder, OneHotEncoder
from sklearn.ensemble import RandomForestRegressor, AdaBoostRegressor
from sklearn.model_selection import cross_val_score, train_test_split
from sklearn.metrics import log_loss, accuracy_score, f1_score, r2_score, mean_squared_error, silhouette_score, normalized_mutual_info_score
from sklearn.decomposition import PCA
from sklearn.linear_model import LinearRegression, ElasticNet, Lasso, HuberRegressor
from sklearn.cluster import KMeans
from sklearn.svm import SVR

# %%
import xgboost as xgb
import lightgbm as lgb
import catboost as cat

from pystacknet.pystacknet import StackNetRegressor
from bayes_opt import BayesianOptimization

# %%
import tensorflow as tf
import keras
from keras import layers, models, optimizers
from keras.regularizers import L1L2
from tensorflow.keras.losses import Huber
import keras.backend as K

es = keras.callbacks.EarlyStopping(patience=10, restore_best_weights=True)
# Out:
# Using TensorFlow backend.

# %%
tr = pd.read_csv('./data/FIFA_train.csv').drop(['id', 'name'], axis=1)
te = pd.read_csv('./data/FIFA_test.csv').drop(['id', 'name'], axis=1)

sub = pd.read_csv('./data/submission.csv')

target = tr['value']
tr = tr.drop('value', axis=1)

# %%
tr['idx'] = np.ones(len(tr))
te['idx'] = np.zeros(len(te))
merge = pd.concat([tr, te])

categorical = ['continent', 'position', 'prefer_foot']
for c in categorical:
    lbe = LabelEncoder()
    merge[c] = lbe.fit_transform(merge[c])
    
dum = pd.get_dummies(merge['position'], prefix='position')
merge = pd.concat([merge, dum], axis=1)
merge = merge.drop('position', axis=1)

merge['age'] = (merge['age'] - np.min(merge['age']))/(np.max(merge['age']) - np.min(merge['age']))

tr = merge[merge['idx'] == 1].drop('idx', axis=1)
te = merge[merge['idx'] == 0].drop('idx', axis=1)

# %%
tr['left_cont'] = tr['contract_until'].copy()
te['left_cont'] = te['contract_until'].copy()

for i in range(len(tr['contract_until'])):
    try:
        tr['contract_until'][i] = int(tr['contract_until'][i])
        tr['left_cont'][i] = int(tr['left_cont'][i]) - 2018
    except:
        tr['contract_until'][i] = int(tr['contract_until'][i][len(tr['contract_until'][i])-4:len(tr['contract_until'][i])])
        tr['left_cont'][i] = tr['contract_until'][i] - 2018
        
for i in range(len(te['contract_until'])):
    try:
        te['contract_until'][i] = int(te['contract_until'][i])
        te['left_cont'][i] = int(te['left_cont'][i]) - 2018
    except:
        te['contract_until'][i] = int(te['contract_until'][i][len(te['contract_until'][i])-4:len(te['contract_until'][i])])
        te['left_cont'][i] = te['contract_until'][i] - 2018

# %%
tr = tr.astype('float')
te = te.astype('float')

# %%
tr['slack'] = tr['stat_potential'] - tr['stat_overall']
te['slack'] = te['stat_potential'] - te['stat_overall']

# %%
tr = tr.drop(['contract_until', 'continent'], axis=1)
te = te.drop(['contract_until', 'continent'], axis=1)

# %%
tr['stat_overall'] /= 100
te['stat_overall'] /= 100

tr['stat_potential'] /= 100
te['stat_potential'] /= 100

tr['reputation'] /= 5
te['reputation'] /= 5

tr['stat_skill_moves'] /= 5
te['stat_skill_moves'] /= 5

# %%
tr.head()
# Out:
#         age  prefer_foot  reputation  stat_overall  stat_potential  \
# 0  0.576923          0.0         1.0          0.94            0.94
# 1  0.423077          1.0         0.8          0.91            0.93
# 2  0.576923          1.0         1.0          0.91            0.91
# 3  0.615385          1.0         0.8          0.91            0.91
# 4  0.346154          1.0         0.6          0.90            0.93
#
#    stat_skill_moves  position_0  position_1  position_2  position_3  \
# 0               0.8         0.0         0.0         0.0         1.0
# 1               0.2         0.0         1.0         0.0         0.0
# 2               0.6         0.0         0.0         0.0         1.0
# 3               0.6         1.0         0.0         0.0         0.0
# 4               0.2         0.0         1.0         0.0         0.0
#
#    left_cont  slack
# 0        3.0    0.0
# 1        2.0    2.0
# 2        3.0    0.0
# 3        2.0    0.0
# 4        3.0    3.0

# %%
sns.distplot(tr['age'])

# %%
train_X = tr.copy()
train_y = target.copy()

test_X = te.copy()

# %%
lr = LinearRegression()
las = Lasso()
els = ElasticNet(l1_ratio=1)
rf = RandomForestRegressor(random_state=12,
                          max_depth=13)

test_models = [lr, las, els, rf]

# %%
for m in test_models:
    print(-1 * round(np.mean(cross_val_score(m, train_X, target, cv=4, scoring='neg_root_mean_squared_error')), 3))

# %%
tr_X, te_X, tr_y, te_y = train_test_split(train_X, target, test_size=0.3, random_state=12, shuffle=True)

# %%
def LGB_bayesian(
    #learning_rate,
    num_leaves, 
    bagging_fraction,
    feature_fraction,
    min_child_weight, 
    min_data_in_leaf,
    max_depth,
    reg_alpha,
    reg_lambda
     ):
    # LightGBM expects next three parameters need to be integer. 
    num_leaves = int(num_leaves)
    min_data_in_leaf = int(min_data_in_leaf)
    max_depth = int(max_depth)

    assert type(num_leaves) == int
    assert type(min_data_in_leaf) == int
    assert type(max_depth) == int
    

    params = {
              'num_leaves': num_leaves, 
              'min_data_in_leaf': min_data_in_leaf,
              'min_child_weight': min_child_weight,
              'bagging_fraction' : bagging_fraction,
              'feature_fraction' : feature_fraction,
#               'learning_rate' : 0.03,
              'max_depth': max_depth,
              'reg_alpha': reg_alpha,
              'reg_lambda': reg_lambda,
              'objective': 'regression',
              'save_binary': True,
              'seed': 12,
              'feature_fraction_seed': 12,
              'bagging_seed': 12,
              'drop_seed': 12,
              'data_random_seed': 12,
              'boosting': 'gbdt', ## some get better result using 'dart'
              'verbose': 1,
              'is_unbalance': False,
              'boost_from_average': True,
              'metric':'rmse'}    
    
    ## set clf options
    clf = lgb.LGBMRegressor(**params).fit(tr_X, tr_y, early_stopping_rounds=100,eval_set=[(te_X, te_y)], eval_metric='rmse', verbose=0)
    
    score = -mean_squared_error(te_y, clf.predict(te_X))/len(te_y)

    return score

# %%
bounds_LGB = {
    'num_leaves': (10, 500), 
    'min_data_in_leaf': (0, 150),
    'bagging_fraction' : (0.1, 0.9),
    'feature_fraction' : (0.1, 0.9),
#     'learning_rate': (0.01, 0.3),
    'min_child_weight': (0.001, 3),   
    'reg_alpha': (0.1, 3), 
    'reg_lambda': (0.1, 3),
    'max_depth':(3, 19),
}

# %%
optimizer = BayesianOptimization(LGB_bayesian, bounds_LGB, random_state=12)

# %%
init_points = 20
n_iter = 20

optimizer.maximize(init_points=init_points, n_iter=n_iter)
# Out:
# |   iter    |  target   | baggin... | featur... | max_depth | min_ch... | min_da... | num_le... | reg_alpha | reg_la... |
# -------------------------------------------------------------------------------------------------------------------------
# |  1        | -3.114e+0 |  0.2233   |  0.692    |  7.213    |  1.602    |  2.186    |  460.2    |  2.712    |  0.1969   |
# |  2        | -2.224e+0 |  0.8656   |  0.2098   |  7.541    |  1.819    |  141.6    |  427.8    |  0.1066   |  1.612    |
# |  3        | -1.817e+0 |  0.5416   |  0.4883   |  15.29    |  0.483    |  114.7    |  20.2     |  0.4921   |  0.4372   |
# |  4        | -7.754e+0 |  0.3479   |  0.6372   |  10.54    |  2.449    |  43.44    |  369.2    |  2.138    |  1.05     |
# |  5        | -1.774e+0 |  0.3677   |  0.8824   |  12.99    |  2.851    |  115.1    |  414.3    |  1.279    |  1.409    |
# |  6        | -1.051e+0 |  0.4205   |  0.8961   |  5.841    |  2.888    |  62.89    |  217.8    |  1.443    |  1.184    |
# |  7        | -2.063e+0 |  0.4724   |  0.1281   |  4.348    |  2.198    |  95.43    |  23.67    |  0.9705   |  0.7405   |
# |  8        | -1.411e+0 |  0.144    |  0.5186   |  9.662    |  0.1456   |  85.86    |  403.7    |  0.4294   |  0.9036   |
# |  9        | -1.951e+0 |  0.6133   |  0.4942   |  11.1     |  1.385    |  134.2    |  306.8    |  1.85     |  1.387    |
# |  10       | -4.448e+0 |  0.484    |  0.8108   |  6.336    |  2.834    |  11.02    |  301.6    |  0.1903   |  2.029    |
# |  11       | -1.511e+0 |  0.6099   |  0.79     |  18.07    |  1.337    |  100.5    |  462.9    |  1.896    |  1.035    |
# |  12       | -2.158e+0 |  0.3556   |  0.3332   |  18.32    |  1.218    |  142.0    |  430.0    |  2.098    |  0.1095   |
# |  13       | -9.979e+0 |  0.8201   |  0.8359   |  3.095    |  1.929    |  57.78    |  301.9    |  1.871    |  1.839    |
# |  14       | -1.244e+0 |  0.3498   |  0.1559   |  15.81    |  2.734    |  29.2     |  113.2    |  1.195    |  1.268    |
# |  15       | -1.573e+0 |  0.8081   |  0.2617   |  9.704    |  1.944    |  76.75    |  173.6    |  2.358    |  0.4928   |
# |  16       | -5.913e+0 |  0.2534   |  0.4221   |  15.59    |  0.7622   |  16.42    |  466.0    |  0.4665   |  1.855    |
# |  17       | -1.041e+0 |  0.3321   |  0.6012   |  13.55    |  0.2041   |  53.32    |  174.0    |  0.6148   |  0.1232   |
# |  18       | -1.972e+0 |  0.1084   |  0.578    |  4.354    |  0.9477   |  145.3    |  438.1    |  2.747    |  0.5927   |
# |  19       | -1.221e+0 |  0.3534   |  0.2934   |  10.86    |  1.632    |  60.82    |  373.8    |  1.967    |  2.012    |
# |  20       | -1.039e+0 |  0.2194   |  0.6973   |  13.26    |  0.8954   |  56.37    |  494.4    |  1.099    |  1.096    |
# |  21       | -3.213e+0 |  0.2248   |  0.6784   |  7.661    |  1.557    |  3.122    |  460.6    |  2.592    |  0.2844   |
# |  22       | -3.24e+08 |  0.2205   |  0.718    |  6.304    |  1.693    |  0.0      |  459.2    |  2.956    |  0.1      |
# |  23       | -3.247e+0 |  0.2204   |  0.7174   |  6.562    |  1.666    |  1.7      |  460.3    |  2.886    |  0.1      |
# |  24       | -3.292e+0 |  0.2379   |  0.5705   |  9.882    |  1.343    |  1.38     |  457.7    |  1.998    |  0.2436   |
# |  25       | -3.522e+0 |  0.2283   |  0.6503   |  8.07     |  1.519    |  1.474    |  459.1    |  2.483    |  1.037    |
# |  26       | -3.067e+0 |  0.2294   |  0.6455   |  8.233    |  1.504    |  2.068    |  459.1    |  2.44     |  0.1      |
# |  27       | -3.478e+0 |  0.2268   |  0.6174   |  8.967    |  1.417    |  0.3219   |  460.5    |  2.239    |  0.1      |
# |  28       | -2.963e+0 |  0.2288   |  0.6606   |  7.576    |  1.573    |  0.2796   |  457.7    |  2.617    |  0.1      |
# |  29       | -2.964e+0 |  0.2301   |  0.654    |  7.66     |  1.567    |  0.0      |  457.2    |  2.595    |  0.1      |
# |  30       | -2.962e+0 |  0.2296   |  0.6582   |  7.608    |  1.572    |  0.1735   |  457.5    |  2.608    |  0.1      |
# |  31       | -2.965e+0 |  0.225    |  0.6364   |  7.724    |  1.544    |  0.0      |  457.5    |  2.576    |  0.1      |
# |  32       | -3.154e+0 |  0.2679   |  0.7954   |  7.599    |  1.697    |  0.15     |  457.5    |  2.619    |  0.1      |
# |  33       | -1.159e+0 |  0.1      |  0.1      |  6.856    |  0.001    |  0.5816   |  457.2    |  2.595    |  0.1      |
# |  34       | -4.448e+0 |  0.484    |  0.8108   |  6.336    |  2.834    |  11.02    |  301.6    |  0.1903   |  2.029    |
# |  35       | -4.448e+0 |  0.484    |  0.8108   |  6.336    |  2.834    |  11.02    |  301.6    |  0.1903   |  2.029    |
# |  36       | -2.947e+0 |  0.2767   |  0.8406   |  7.911    |  1.658    |  2.997    |  460.7    |  2.227    |  0.9018   |
# |  37       | -2.866e+0 |  0.2135   |  0.6266   |  7.952    |  1.646    |  1.011    |  459.5    |  2.495    |  0.143    |
# |  38       | -3.426e+0 |  0.2558   |  0.7686   |  7.918    |  1.622    |  2.569    |  460.4    |  2.354    |  0.5935   |
# |  39       | -3.404e+0 |  0.2064   |  0.5608   |  8.509    |  1.569    |  1.128    |  458.6    |  2.399    |  0.1881   |
# |  40       | -2.955e+0 |  0.2153   |  0.6727   |  7.066    |  1.698    |  0.7714   |  459.4    |  2.773    |  0.1607   |
# =========================================================================================================================

# %%
param_lgb = {
        'min_data_in_leaf': int(optimizer.max['params']['min_data_in_leaf']), 
        'num_leaves': int(optimizer.max['params']['num_leaves']), 
        #'learning_rate': LGB_BO.max['params']['learning_rate'],
        'min_child_weight': optimizer.max['params']['min_child_weight'],
        'bagging_fraction': optimizer.max['params']['bagging_fraction'], 
        'feature_fraction': optimizer.max['params']['feature_fraction'],
        'reg_lambda': optimizer.max['params']['reg_lambda'],
        'reg_alpha': optimizer.max['params']['reg_alpha'],
        'max_depth': int(optimizer.max['params']['max_depth']), 
        'objective': 'regression',
        'save_binary': True,
        'seed': 12,
        'feature_fraction_seed': 12,
        'bagging_seed': 12,
        'drop_seed': 12,
        'data_random_seed': 12,
        'boosting_type': 'gbdt',  # also consider 'dart'
        'verbose': 1,
        'is_unbalance': False,
        'boost_from_average': True,
        'metric':'rmse'
    }

params = param_lgb.copy()

# %%
lgb_clf = lgb.LGBMRegressor(**params, early_stoppong_rounds = 100)
lgb_clf.fit(train_X, target)
# Out:
# LGBMRegressor(bagging_fraction=0.21352301463492807, bagging_seed=12,
#               boost_from_average=True, boosting_type='gbdt', class_weight=None,
#               colsample_bytree=1.0, data_random_seed=12, drop_seed=12,
#               early_stoppong_rounds=100, feature_fraction=0.6266369578052369,
#               feature_fraction_seed=12, importance_type='split',
#               is_unbalance=False, learning_rate=0.1, max_depth=7, metric='rmse',
#               min_child_samples=20, min_child_weight=1.6463011973330988,
#               min_data_in_leaf=1, min_split_gain=0.0, n_estimators=100,
#               n_jobs=-1, num_leaves=459, objective='regression',
#               random_state=None, reg_alpha=2.4953852940360384,
#               reg_lambda=0.1430473985570573, save_binary=True, seed=12,
#               silent=True, ...)

# %%
sub['value'] = lgb_clf.predict(test_X)
print(sub)
# Out:
#          id         value
# 0         1  7.374257e+07
# 1         2  1.058097e+08
# 2         4  6.953201e+07
# 3         5  7.238886e+07
# 4         6  6.256181e+07
# ...     ...           ...
# 3823  16924  8.344692e+04
# 3824  16929  6.467118e+04
# 3825  16932  7.770136e+04
# 3826  16937  5.971908e+04
# 3827  16943  5.667375e+04
#
# [3828 rows x 2 columns]

# %%
sub.to_csv('./sub/pre/lgb2.csv', index=False)

# %%
# parmas for xgboost
params_fx = {'min_data_in_leaf': params['min_data_in_leaf'],
             'num_leaves': params['num_leaves'],
             'min_child_weight': params['min_child_weight'],
             'bagging_fraction': params['bagging_fraction'],
             'feature_fraction': params['feature_fraction'],
             'reg_lambda': params['reg_lambda'],
             'reg_alpha': params['reg_alpha'],
             'max_depth': params['max_depth'],
#              'obective': 'reg:squarederror',
             'eval_metric': 'rmse'
             
}

# %%
xgb_clf = xgb.XGBRegressor(
            **params_fx,
            early_stoppong_rounds = 100         
    ).fit(train_X.values, target)
# Out:
# [11:44:11] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.

# %%
sub['value'] = xgb_clf.predict(test_X.values)
print(sub)
# Out:
#          id         value
# 0         1  6.378290e+07
# 1         2  1.059075e+08
# 2         4  7.039196e+07
# 3         5  7.172346e+07
# 4         6  6.067336e+07
# ...     ...           ...
# 3823  16924  7.882162e+04
# 3824  16929  3.336033e+04
# 3825  16932  6.518775e+04
# 3826  16937  7.228119e+04
# 3827  16943  7.354127e+04
#
# [3828 rows x 2 columns]

# %%
sub.to_csv('./sub/pre/xgb2.csv', index=False)

# %%
cat_clf = cat.CatBoostRegressor(random_seed=42, n_estimators=1500, early_stopping_rounds=50, learning_rate=0.5).fit(train_X, target)
# Out:
# 0:	learn: 3590583.5106852	total: 66.5ms	remaining: 1m 39s
# 1:	learn: 2413048.4525564	total: 68ms	remaining: 51s
# 2:	learn: 1679248.3999477	total: 69.8ms	remaining: 34.8s
# 3:	learn: 1262328.6547248	total: 71.5ms	remaining: 26.7s
# 4:	learn: 1042310.0214422	total: 73.1ms	remaining: 21.9s
# 5:	learn: 1011383.8608316	total: 74.4ms	remaining: 18.5s
# 6:	learn: 921070.9470389	total: 75.9ms	remaining: 16.2s
# 7:	learn: 903961.5101294	total: 77.1ms	remaining: 14.4s
# 8:	learn: 887364.3723581	total: 78.5ms	remaining: 13s
# 9:	learn: 849628.5087261	total: 79.7ms	remaining: 11.9s
# 10:	learn: 836145.0636925	total: 81.1ms	remaining: 11s
# 11:	learn: 770190.3887171	total: 82.9ms	remaining: 10.3s
# 12:	learn: 760485.5044871	total: 84.3ms	remaining: 9.65s
# 13:	learn: 714062.9813750	total: 85.8ms	remaining: 9.11s
# 14:	learn: 662123.2584750	total: 87.3ms	remaining: 8.65s
# 15:	learn: 656652.3884498	total: 92.9ms	remaining: 8.62s
# 16:	learn: 652498.7599791	total: 94.3ms	remaining: 8.23s
# 17:	learn: 628941.7746565	total: 95.8ms	remaining: 7.89s
# 18:	learn: 625719.0149679	total: 97.1ms	remaining: 7.57s
# 19:	learn: 604164.1126957	total: 98.5ms	remaining: 7.29s
# 20:	learn: 574785.4305573	total: 100ms	remaining: 7.05s
# 21:	learn: 573527.0540904	total: 101ms	remaining: 6.79s
# 22:	learn: 544728.8989651	total: 103ms	remaining: 6.6s
# 23:	learn: 528343.2292889	total: 104ms	remaining: 6.41s
# 24:	learn: 513230.3102533	total: 106ms	remaining: 6.23s
# 25:	learn: 503903.8695860	total: 107ms	remaining: 6.07s
# 26:	learn: 482058.5457336	total: 109ms	remaining: 5.92s
# 27:	learn: 463675.2025749	total: 110ms	remaining: 5.79s
# 28:	learn: 449649.5253404	total: 112ms	remaining: 5.68s
# 29:	learn: 442398.1806161	total: 113ms	remaining: 5.56s
# 30:	learn: 429514.9441844	total: 115ms	remaining: 5.45s
# 31:	learn: 417426.4656198	total: 116ms	remaining: 5.34s
# 32:	learn: 402610.1528668	total: 118ms	remaining: 5.24s
# 33:	learn: 393399.4019244	total: 119ms	remaining: 5.15s
# 34:	learn: 389743.7381868	total: 121ms	remaining: 5.08s
# 35:	learn: 382769.4815485	total: 123ms	remaining: 5.01s
# 36:	learn: 376165.3357790	total: 125ms	remaining: 4.94s
# 37:	learn: 369923.7957670	total: 127ms	remaining: 4.87s
# 38:	learn: 362229.7696119	total: 128ms	remaining: 4.8s
# 39:	learn: 354726.6244854	total: 130ms	remaining: 4.74s
# 40:	learn: 349806.5305959	total: 132ms	remaining: 4.68s
# 41:	learn: 343291.1336250	total: 133ms	remaining: 4.62s
# 42:	learn: 335973.1148312	total: 135ms	remaining: 4.56s
# 43:	learn: 330648.9922945	total: 136ms	remaining: 4.5s
# 44:	learn: 327922.5991505	total: 138ms	remaining: 4.45s
# 45:	learn: 322816.0901316	total: 139ms	remaining: 4.4s
# 46:	learn: 317297.0524778	total: 141ms	remaining: 4.35s
# 47:	learn: 312422.0956403	total: 142ms	remaining: 4.31s
# 48:	learn: 308517.2562227	total: 144ms	remaining: 4.26s
# 49:	learn: 306319.3578704	total: 145ms	remaining: 4.21s
# 50:	learn: 303785.2297645	total: 147ms	remaining: 4.17s
# 51:	learn: 298876.6731925	total: 148ms	remaining: 4.13s
# 52:	learn: 293265.6236956	total: 150ms	remaining: 4.09s
# 53:	learn: 289239.0369750	total: 151ms	remaining: 4.05s
# 54:	learn: 287508.6490079	total: 153ms	remaining: 4.02s
# 55:	learn: 286982.9600769	total: 154ms	remaining: 3.98s
# 56:	learn: 283398.8563740	total: 156ms	remaining: 3.95s
# 57:	learn: 281327.8732873	total: 158ms	remaining: 3.92s
# 58:	learn: 278483.1392656	total: 159ms	remaining: 3.89s
# 59:	learn: 276755.1215320	total: 161ms	remaining: 3.86s
# 60:	learn: 274459.4956468	total: 162ms	remaining: 3.83s
# 61:	learn: 271009.4726805	total: 164ms	remaining: 3.8s
# 62:	learn: 269450.2654377	total: 166ms	remaining: 3.78s
# 63:	learn: 265270.5015482	total: 167ms	remaining: 3.75s
# 64:	learn: 264203.1595898	total: 169ms	remaining: 3.72s
# 65:	learn: 263705.8590863	total: 170ms	remaining: 3.69s
# 66:	learn: 262015.0087093	total: 172ms	remaining: 3.67s
# 67:	learn: 259637.6222968	total: 173ms	remaining: 3.65s
# 68:	learn: 257396.3900000	total: 175ms	remaining: 3.62s
# 69:	learn: 256356.3514740	total: 176ms	remaining: 3.6s
# 70:	learn: 254803.8247076	total: 178ms	remaining: 3.57s
# 71:	learn: 254249.6400759	total: 179ms	remaining: 3.56s
# 72:	learn: 251748.9083874	total: 181ms	remaining: 3.53s
# 73:	learn: 251517.1730101	total: 182ms	remaining: 3.51s
# 74:	learn: 249040.8373227	total: 184ms	remaining: 3.49s
# 75:	learn: 247896.1056522	total: 185ms	remaining: 3.47s
# 76:	learn: 247611.1179042	total: 187ms	remaining: 3.45s
# 77:	learn: 245751.8419934	total: 188ms	remaining: 3.43s
# 78:	learn: 243656.7209618	total: 190ms	remaining: 3.42s
# 79:	learn: 242666.4951194	total: 191ms	remaining: 3.4s
# 80:	learn: 240879.3247551	total: 193ms	remaining: 3.38s
# 81:	learn: 239284.6664023	total: 195ms	remaining: 3.36s
# 82:	learn: 236899.4756491	total: 196ms	remaining: 3.35s
# 83:	learn: 235331.5462254	total: 197ms	remaining: 3.33s
# 84:	learn: 234721.0628251	total: 199ms	remaining: 3.31s
# 85:	learn: 232484.2225680	total: 200ms	remaining: 3.29s
# 86:	learn: 230643.9525191	total: 202ms	remaining: 3.28s
# 87:	learn: 228761.6930721	total: 204ms	remaining: 3.27s
# 88:	learn: 227463.4766900	total: 205ms	remaining: 3.25s
# 89:	learn: 226697.0195891	total: 206ms	remaining: 3.23s
# 90:	learn: 225633.0345336	total: 209ms	remaining: 3.23s
# 91:	learn: 225319.3686163	total: 210ms	remaining: 3.22s
# 92:	learn: 224095.3102498	total: 212ms	remaining: 3.2s
# 93:	learn: 221953.2551011	total: 213ms	remaining: 3.19s
# 94:	learn: 221008.0099749	total: 215ms	remaining: 3.18s
# 95:	learn: 219778.5799841	total: 216ms	remaining: 3.16s
# 96:	learn: 218950.6575448	total: 218ms	remaining: 3.15s
# 97:	learn: 217763.7967002	total: 219ms	remaining: 3.14s
# 98:	learn: 216576.5111115	total: 221ms	remaining: 3.13s
# 99:	learn: 215643.7242251	total: 222ms	remaining: 3.11s
# 100:	learn: 214545.7387882	total: 224ms	remaining: 3.1s
# 101:	learn: 213592.1161301	total: 226ms	remaining: 3.09s
# 102:	learn: 212797.7733150	total: 227ms	remaining: 3.08s
# 103:	learn: 211713.0721545	total: 229ms	remaining: 3.07s
# 104:	learn: 210051.7714167	total: 230ms	remaining: 3.06s
# 105:	learn: 209265.1573816	total: 232ms	remaining: 3.05s
# 106:	learn: 208397.5838600	total: 233ms	remaining: 3.04s
# 107:	learn: 206893.9904305	total: 235ms	remaining: 3.03s
# 108:	learn: 206258.4114249	total: 237ms	remaining: 3.02s
# 109:	learn: 205984.8804613	total: 239ms	remaining: 3.02s
# 110:	learn: 204887.7368755	total: 240ms	remaining: 3.01s
# 111:	learn: 204711.7270981	total: 242ms	remaining: 3s
# 112:	learn: 203883.4421481	total: 244ms	remaining: 2.99s
# 113:	learn: 202537.8077144	total: 245ms	remaining: 2.98s
# 114:	learn: 202083.2950232	total: 247ms	remaining: 2.97s
# 115:	learn: 201065.1308065	total: 248ms	remaining: 2.96s
# 116:	learn: 201026.1450828	total: 250ms	remaining: 2.95s
# 117:	learn: 200509.8808978	total: 251ms	remaining: 2.94s
# 118:	learn: 199134.0835534	total: 253ms	remaining: 2.93s
# 119:	learn: 198755.6265824	total: 255ms	remaining: 2.93s
# 120:	learn: 197984.7698905	total: 256ms	remaining: 2.92s
# 121:	learn: 197328.0150084	total: 258ms	remaining: 2.91s
# 122:	learn: 197001.7962055	total: 259ms	remaining: 2.9s
# 123:	learn: 196545.7222912	total: 261ms	remaining: 2.89s
# 124:	learn: 195714.8080175	total: 262ms	remaining: 2.89s
# 125:	learn: 194841.6784203	total: 264ms	remaining: 2.88s
# 126:	learn: 194288.4572421	total: 266ms	remaining: 2.87s
# 127:	learn: 192745.4097703	total: 267ms	remaining: 2.86s
# 128:	learn: 192720.5455195	total: 269ms	remaining: 2.85s
# 129:	learn: 192045.4502130	total: 270ms	remaining: 2.85s
# 130:	learn: 191615.7345491	total: 273ms	remaining: 2.85s
# 131:	learn: 191382.0963065	total: 274ms	remaining: 2.84s
# 132:	learn: 191121.7130425	total: 276ms	remaining: 2.83s
# 133:	learn: 190798.1466098	total: 277ms	remaining: 2.82s
# 134:	learn: 190658.6498700	total: 279ms	remaining: 2.82s
# 135:	learn: 190550.3471802	total: 280ms	remaining: 2.81s
# 136:	learn: 189489.5092372	total: 282ms	remaining: 2.8s
# 137:	learn: 188689.5995221	total: 283ms	remaining: 2.79s
# 138:	learn: 187617.6975535	total: 285ms	remaining: 2.79s
# 139:	learn: 187159.2716738	total: 286ms	remaining: 2.78s
# 140:	learn: 186335.1764634	total: 288ms	remaining: 2.77s
# 141:	learn: 185625.7253841	total: 290ms	remaining: 2.77s
# 142:	learn: 185394.0957993	total: 291ms	remaining: 2.76s
# 143:	learn: 184882.6783553	total: 292ms	remaining: 2.75s
# 144:	learn: 184365.8373237	total: 297ms	remaining: 2.78s
# 145:	learn: 184048.3579686	total: 299ms	remaining: 2.77s
# 146:	learn: 183881.0281513	total: 301ms	remaining: 2.77s
# 147:	learn: 183785.7570311	total: 302ms	remaining: 2.76s
# 148:	learn: 182922.3710747	total: 304ms	remaining: 2.75s
# 149:	learn: 182426.1624221	total: 305ms	remaining: 2.75s
# 150:	learn: 181742.3769896	total: 307ms	remaining: 2.74s
# 151:	learn: 181591.1025110	total: 308ms	remaining: 2.73s
# 152:	learn: 181062.8782873	total: 310ms	remaining: 2.73s
# 153:	learn: 179813.0745987	total: 312ms	remaining: 2.73s
# 154:	learn: 179567.5002000	total: 314ms	remaining: 2.72s
# 155:	learn: 179234.8537405	total: 315ms	remaining: 2.72s
# 156:	learn: 179076.0697911	total: 317ms	remaining: 2.71s
# 157:	learn: 178382.1762376	total: 318ms	remaining: 2.7s
# 158:	learn: 177460.1219710	total: 320ms	remaining: 2.7s
# 159:	learn: 176529.3054746	total: 321ms	remaining: 2.69s
# 160:	learn: 176322.7645763	total: 323ms	remaining: 2.69s
# 161:	learn: 175721.6294226	total: 325ms	remaining: 2.69s
# 162:	learn: 175359.1117421	total: 327ms	remaining: 2.68s
# 163:	learn: 174913.5882631	total: 329ms	remaining: 2.68s
# 164:	learn: 174237.1349431	total: 330ms	remaining: 2.67s
# 165:	learn: 174024.9259017	total: 332ms	remaining: 2.67s
# 166:	learn: 173303.8652449	total: 333ms	remaining: 2.66s
# 167:	learn: 172952.9949334	total: 335ms	remaining: 2.66s
# 168:	learn: 172753.7737381	total: 337ms	remaining: 2.65s
# 169:	learn: 172447.4486036	total: 339ms	remaining: 2.65s
# 170:	learn: 172081.8025279	total: 340ms	remaining: 2.65s
# 171:	learn: 171957.6436729	total: 342ms	remaining: 2.64s
# 172:	learn: 171795.7483587	total: 344ms	remaining: 2.63s
# 173:	learn: 171401.5750229	total: 345ms	remaining: 2.63s
# 174:	learn: 170704.7683534	total: 347ms	remaining: 2.63s
# 175:	learn: 170558.3486654	total: 349ms	remaining: 2.62s
# 176:	learn: 169822.9068534	total: 350ms	remaining: 2.62s
# 177:	learn: 169643.4857945	total: 352ms	remaining: 2.61s
# 178:	learn: 168726.8376298	total: 355ms	remaining: 2.62s
# 179:	learn: 168556.3852970	total: 356ms	remaining: 2.61s
# 180:	learn: 168541.0990961	total: 358ms	remaining: 2.61s
# 181:	learn: 168155.6496266	total: 360ms	remaining: 2.61s
# 182:	learn: 167963.7567414	total: 362ms	remaining: 2.6s
# 183:	learn: 167378.2081901	total: 363ms	remaining: 2.6s
# 184:	learn: 167364.8495291	total: 365ms	remaining: 2.59s
# 185:	learn: 166875.1660630	total: 366ms	remaining: 2.59s
# 186:	learn: 166651.0989005	total: 368ms	remaining: 2.58s
# 187:	learn: 166645.5277279	total: 369ms	remaining: 2.58s
# 188:	learn: 166310.5821132	total: 371ms	remaining: 2.57s
# 189:	learn: 166140.2301164	total: 373ms	remaining: 2.57s
# 190:	learn: 165742.8955329	total: 375ms	remaining: 2.57s
# 191:	learn: 165229.1630337	total: 376ms	remaining: 2.56s
# 192:	learn: 164821.6338353	total: 378ms	remaining: 2.56s
# 193:	learn: 163580.1933325	total: 380ms	remaining: 2.56s
# 194:	learn: 163160.4036292	total: 382ms	remaining: 2.56s
# 195:	learn: 162862.5516721	total: 383ms	remaining: 2.55s
# 196:	learn: 162654.3382694	total: 385ms	remaining: 2.54s
# 197:	learn: 162218.4455363	total: 386ms	remaining: 2.54s
# 198:	learn: 161967.7330961	total: 388ms	remaining: 2.54s
# 199:	learn: 161757.4576886	total: 389ms	remaining: 2.53s
# 200:	learn: 161625.1457381	total: 391ms	remaining: 2.52s
# 201:	learn: 161223.5761173	total: 392ms	remaining: 2.52s
# 202:	learn: 160601.1793608	total: 394ms	remaining: 2.52s
# 203:	learn: 160369.2780388	total: 395ms	remaining: 2.51s
# 204:	learn: 160258.6928580	total: 397ms	remaining: 2.51s
# 205:	learn: 160105.6862636	total: 399ms	remaining: 2.51s
# 206:	learn: 159537.5620161	total: 401ms	remaining: 2.5s
# 207:	learn: 159514.7839993	total: 402ms	remaining: 2.5s
# 208:	learn: 159354.2518311	total: 404ms	remaining: 2.5s
# 209:	learn: 159146.1733253	total: 406ms	remaining: 2.49s
# 210:	learn: 158922.8507463	total: 407ms	remaining: 2.49s
# 211:	learn: 158520.0000584	total: 409ms	remaining: 2.48s
# 212:	learn: 157803.7441440	total: 411ms	remaining: 2.48s
# 213:	learn: 157172.1235310	total: 412ms	remaining: 2.48s
# 214:	learn: 156570.2669097	total: 414ms	remaining: 2.47s
# 215:	learn: 156221.6761236	total: 415ms	remaining: 2.47s
# 216:	learn: 155544.8490352	total: 417ms	remaining: 2.46s
# 217:	learn: 154954.0864286	total: 418ms	remaining: 2.46s
# 218:	learn: 154513.8572201	total: 420ms	remaining: 2.46s
# 219:	learn: 154290.5377676	total: 422ms	remaining: 2.45s
# 220:	learn: 154035.1307888	total: 423ms	remaining: 2.45s
# 221:	learn: 153360.2807173	total: 425ms	remaining: 2.45s
# 222:	learn: 153120.4517279	total: 427ms	remaining: 2.44s
# 223:	learn: 152944.9142991	total: 428ms	remaining: 2.44s
# 224:	learn: 152609.9214813	total: 430ms	remaining: 2.44s
# 225:	learn: 151763.8184809	total: 432ms	remaining: 2.43s
# 226:	learn: 151551.0837685	total: 433ms	remaining: 2.43s
# 227:	learn: 151043.9865081	total: 435ms	remaining: 2.43s
# 228:	learn: 150341.8196623	total: 437ms	remaining: 2.42s
# 229:	learn: 150164.5017092	total: 439ms	remaining: 2.42s
# 230:	learn: 149706.6039529	total: 440ms	remaining: 2.42s
# 231:	learn: 149591.6862048	total: 442ms	remaining: 2.41s
# 232:	learn: 149349.9400051	total: 443ms	remaining: 2.41s
# 233:	learn: 148915.6445275	total: 445ms	remaining: 2.41s
# 234:	learn: 148371.0750559	total: 447ms	remaining: 2.4s
# 235:	learn: 147581.4359661	total: 448ms	remaining: 2.4s
# 236:	learn: 147328.0064420	total: 450ms	remaining: 2.4s
# 237:	learn: 147091.1889205	total: 452ms	remaining: 2.4s
# 238:	learn: 146605.1617323	total: 454ms	remaining: 2.39s
# 239:	learn: 146463.6704906	total: 455ms	remaining: 2.39s
# 240:	learn: 146238.9268736	total: 457ms	remaining: 2.39s
# 241:	learn: 145979.1680863	total: 459ms	remaining: 2.38s
# 242:	learn: 145729.6176546	total: 460ms	remaining: 2.38s
# 243:	learn: 145634.3573347	total: 462ms	remaining: 2.38s
# 244:	learn: 145465.4699110	total: 463ms	remaining: 2.37s
# 245:	learn: 145403.3224517	total: 465ms	remaining: 2.37s
# 246:	learn: 145018.2897969	total: 467ms	remaining: 2.37s
# 247:	learn: 144863.3892518	total: 469ms	remaining: 2.37s
# 248:	learn: 144824.4654206	total: 470ms	remaining: 2.36s
# 249:	learn: 144716.3903725	total: 472ms	remaining: 2.36s
# 250:	learn: 144633.0530700	total: 473ms	remaining: 2.35s
# 251:	learn: 144520.3854056	total: 475ms	remaining: 2.35s
# 252:	learn: 144515.5775642	total: 476ms	remaining: 2.35s
# 253:	learn: 144158.1511555	total: 478ms	remaining: 2.34s
# 254:	learn: 143949.1223125	total: 479ms	remaining: 2.34s
# 255:	learn: 143889.7079666	total: 480ms	remaining: 2.33s
# 256:	learn: 143183.1863512	total: 482ms	remaining: 2.33s
# 257:	learn: 143160.7430918	total: 484ms	remaining: 2.33s
# 258:	learn: 143118.9892515	total: 486ms	remaining: 2.33s
# 259:	learn: 142672.4429868	total: 488ms	remaining: 2.33s
# 260:	learn: 142649.9702587	total: 489ms	remaining: 2.32s
# 261:	learn: 142477.1609401	total: 491ms	remaining: 2.32s
# 262:	learn: 142324.6908911	total: 492ms	remaining: 2.32s
# 263:	learn: 142239.7130937	total: 494ms	remaining: 2.31s
# 264:	learn: 142053.3660435	total: 496ms	remaining: 2.31s
# 265:	learn: 142000.9511747	total: 497ms	remaining: 2.31s
# 266:	learn: 141879.1525867	total: 499ms	remaining: 2.3s
# 267:	learn: 141657.6769814	total: 500ms	remaining: 2.3s
# 268:	learn: 141360.6926327	total: 502ms	remaining: 2.3s
# 269:	learn: 141179.8676837	total: 503ms	remaining: 2.29s
# 270:	learn: 141016.8141669	total: 505ms	remaining: 2.29s
# 271:	learn: 140771.4270208	total: 507ms	remaining: 2.29s
# 272:	learn: 140629.0302494	total: 509ms	remaining: 2.29s
# 273:	learn: 139859.8653759	total: 511ms	remaining: 2.29s
# 274:	learn: 139685.8094828	total: 513ms	remaining: 2.28s
# 275:	learn: 139591.2009118	total: 514ms	remaining: 2.28s
# 276:	learn: 139248.9601219	total: 516ms	remaining: 2.28s
# 277:	learn: 138935.9744133	total: 517ms	remaining: 2.27s
# 278:	learn: 138832.7687647	total: 519ms	remaining: 2.27s
# 279:	learn: 138072.2506675	total: 520ms	remaining: 2.27s
# 280:	learn: 137888.0421028	total: 522ms	remaining: 2.26s
# 281:	learn: 137645.7314127	total: 524ms	remaining: 2.26s
# 282:	learn: 136928.4865725	total: 525ms	remaining: 2.26s
# 283:	learn: 136462.0510184	total: 527ms	remaining: 2.25s
# 284:	learn: 136372.8421884	total: 528ms	remaining: 2.25s
# 285:	learn: 136331.9736597	total: 530ms	remaining: 2.25s
# 286:	learn: 136142.3426782	total: 531ms	remaining: 2.25s
# 287:	learn: 135969.1169213	total: 533ms	remaining: 2.24s
# 288:	learn: 135965.7242019	total: 536ms	remaining: 2.24s
# 289:	learn: 135929.1106123	total: 537ms	remaining: 2.24s
# 290:	learn: 135726.8040850	total: 539ms	remaining: 2.24s
# 291:	learn: 135622.0563473	total: 541ms	remaining: 2.24s
# 292:	learn: 135585.9617839	total: 542ms	remaining: 2.23s
# 293:	learn: 135289.0418374	total: 544ms	remaining: 2.23s
# 294:	learn: 135277.0735249	total: 545ms	remaining: 2.23s
# 295:	learn: 135030.8891101	total: 547ms	remaining: 2.22s
# 296:	learn: 134747.7121267	total: 548ms	remaining: 2.22s
# 297:	learn: 134253.2601120	total: 550ms	remaining: 2.22s
# 298:	learn: 134107.4784679	total: 552ms	remaining: 2.22s
# 299:	learn: 133988.0008606	total: 553ms	remaining: 2.21s
# 300:	learn: 133986.1082943	total: 555ms	remaining: 2.21s
# 301:	learn: 133888.4914048	total: 557ms	remaining: 2.21s
# 302:	learn: 133622.1826251	total: 558ms	remaining: 2.21s
# 303:	learn: 133528.6463671	total: 560ms	remaining: 2.2s
# 304:	learn: 133356.9472469	total: 561ms	remaining: 2.2s
# 305:	learn: 133346.5402326	total: 563ms	remaining: 2.2s
# 306:	learn: 133338.5731379	total: 566ms	remaining: 2.2s
# 307:	learn: 133101.2826794	total: 567ms	remaining: 2.19s
# 308:	learn: 132946.1947560	total: 569ms	remaining: 2.19s
# 309:	learn: 132875.2183491	total: 570ms	remaining: 2.19s
# 310:	learn: 132819.2103613	total: 572ms	remaining: 2.19s
# 311:	learn: 132593.7020930	total: 573ms	remaining: 2.18s
# 312:	learn: 132483.4284755	total: 575ms	remaining: 2.18s
# 313:	learn: 132025.7706870	total: 577ms	remaining: 2.18s
# 314:	learn: 131945.9020224	total: 578ms	remaining: 2.17s
# 315:	learn: 131773.9202699	total: 580ms	remaining: 2.17s
# 316:	learn: 131518.5344788	total: 582ms	remaining: 2.17s
# 317:	learn: 131442.9592380	total: 583ms	remaining: 2.17s
# 318:	learn: 131341.6708990	total: 585ms	remaining: 2.16s
# 319:	learn: 131142.7448906	total: 586ms	remaining: 2.16s
# 320:	learn: 131034.3455000	total: 588ms	remaining: 2.16s
# 321:	learn: 130717.5239367	total: 590ms	remaining: 2.16s
# 322:	learn: 130540.3671489	total: 591ms	remaining: 2.15s
# 323:	learn: 130523.9157570	total: 593ms	remaining: 2.15s
# 324:	learn: 130482.4706557	total: 594ms	remaining: 2.15s
# 325:	learn: 130428.3283150	total: 596ms	remaining: 2.15s
# 326:	learn: 130325.2453733	total: 597ms	remaining: 2.14s
# 327:	learn: 130243.8859122	total: 599ms	remaining: 2.14s
# 328:	learn: 129547.4193668	total: 600ms	remaining: 2.14s
# 329:	learn: 129475.4496538	total: 602ms	remaining: 2.13s
# 330:	learn: 129292.6760512	total: 603ms	remaining: 2.13s
# 331:	learn: 129186.7514146	total: 605ms	remaining: 2.13s
# 332:	learn: 129125.8849618	total: 606ms	remaining: 2.12s
# 333:	learn: 128767.5294320	total: 608ms	remaining: 2.12s
# 334:	learn: 128668.5471577	total: 609ms	remaining: 2.12s
# 335:	learn: 128637.1986319	total: 611ms	remaining: 2.12s
# 336:	learn: 128239.5795261	total: 612ms	remaining: 2.11s
# 337:	learn: 127929.6536693	total: 614ms	remaining: 2.11s
# 338:	learn: 127909.1385856	total: 615ms	remaining: 2.11s
# 339:	learn: 127659.2805062	total: 617ms	remaining: 2.1s
# 340:	learn: 127562.9053742	total: 618ms	remaining: 2.1s
# 341:	learn: 127373.5977721	total: 620ms	remaining: 2.1s
# 342:	learn: 127188.2375845	total: 622ms	remaining: 2.1s
# 343:	learn: 127145.2753378	total: 623ms	remaining: 2.09s
# 344:	learn: 126992.4906449	total: 625ms	remaining: 2.09s
# 345:	learn: 126894.2608862	total: 626ms	remaining: 2.09s
# 346:	learn: 126832.6461146	total: 628ms	remaining: 2.08s
# 347:	learn: 126692.3458479	total: 629ms	remaining: 2.08s
# 348:	learn: 126599.8512778	total: 631ms	remaining: 2.08s
# 349:	learn: 126579.0468996	total: 632ms	remaining: 2.08s
# 350:	learn: 126540.4769683	total: 634ms	remaining: 2.07s
# 351:	learn: 126485.7061545	total: 635ms	remaining: 2.07s
# 352:	learn: 126378.9151940	total: 637ms	remaining: 2.07s
# 353:	learn: 126131.2921777	total: 638ms	remaining: 2.06s
# 354:	learn: 126011.7432962	total: 640ms	remaining: 2.06s
# 355:	learn: 125993.9395798	total: 641ms	remaining: 2.06s
# 356:	learn: 125691.2174885	total: 643ms	remaining: 2.06s
# 357:	learn: 125575.0888947	total: 644ms	remaining: 2.06s
# 358:	learn: 125273.4074697	total: 646ms	remaining: 2.05s
# 359:	learn: 125260.4272191	total: 648ms	remaining: 2.05s
# 360:	learn: 125224.7387581	total: 649ms	remaining: 2.05s
# 361:	learn: 124931.9689059	total: 651ms	remaining: 2.05s
# 362:	learn: 124588.0709570	total: 652ms	remaining: 2.04s
# 363:	learn: 124318.4268499	total: 654ms	remaining: 2.04s
# 364:	learn: 124014.9150620	total: 655ms	remaining: 2.04s
# 365:	learn: 123743.3516002	total: 657ms	remaining: 2.04s
# 366:	learn: 123459.8930357	total: 658ms	remaining: 2.03s
# 367:	learn: 123088.1154551	total: 660ms	remaining: 2.03s
# 368:	learn: 122724.2677190	total: 661ms	remaining: 2.03s
# 369:	learn: 122521.9518218	total: 663ms	remaining: 2.02s
# 370:	learn: 122419.4016837	total: 665ms	remaining: 2.02s
# 371:	learn: 122234.1604502	total: 666ms	remaining: 2.02s
# 372:	learn: 121929.4804068	total: 668ms	remaining: 2.02s
# 373:	learn: 121604.4005541	total: 669ms	remaining: 2.01s
# 374:	learn: 121571.3146249	total: 671ms	remaining: 2.01s
# 375:	learn: 121544.4293820	total: 672ms	remaining: 2.01s
# 376:	learn: 121315.6468800	total: 674ms	remaining: 2.01s
# 377:	learn: 121038.3519533	total: 676ms	remaining: 2s
# 378:	learn: 120890.2015118	total: 677ms	remaining: 2s
# 379:	learn: 120693.6237015	total: 679ms	remaining: 2s
# 380:	learn: 120628.2932108	total: 680ms	remaining: 2s
# 381:	learn: 120470.6916870	total: 682ms	remaining: 2s
# 382:	learn: 120447.5598447	total: 683ms	remaining: 1.99s
# 383:	learn: 120381.1825428	total: 685ms	remaining: 1.99s
# 384:	learn: 120307.4206749	total: 686ms	remaining: 1.99s
# 385:	learn: 120221.1430955	total: 688ms	remaining: 1.98s
# 386:	learn: 120218.3717350	total: 689ms	remaining: 1.98s
# 387:	learn: 119995.0916292	total: 691ms	remaining: 1.98s
# 388:	learn: 119972.2674788	total: 692ms	remaining: 1.98s
# 389:	learn: 119769.1495953	total: 694ms	remaining: 1.97s
# 390:	learn: 119705.6359094	total: 695ms	remaining: 1.97s
# 391:	learn: 119317.0517146	total: 697ms	remaining: 1.97s
# 392:	learn: 119281.9119701	total: 698ms	remaining: 1.97s
# 393:	learn: 119148.9703748	total: 700ms	remaining: 1.96s
# 394:	learn: 118833.1271921	total: 701ms	remaining: 1.96s
# 395:	learn: 118763.5996944	total: 703ms	remaining: 1.96s
# 396:	learn: 118434.3313282	total: 705ms	remaining: 1.96s
# 397:	learn: 118341.1885451	total: 706ms	remaining: 1.96s
# 398:	learn: 118302.6134252	total: 708ms	remaining: 1.95s
# 399:	learn: 118246.4056693	total: 709ms	remaining: 1.95s
# 400:	learn: 118115.8748031	total: 711ms	remaining: 1.95s
# 401:	learn: 117959.4537331	total: 713ms	remaining: 1.95s
# 402:	learn: 117781.0549439	total: 714ms	remaining: 1.94s
# 403:	learn: 117676.6099116	total: 716ms	remaining: 1.94s
# 404:	learn: 117577.8001037	total: 717ms	remaining: 1.94s
# 405:	learn: 117508.1478083	total: 719ms	remaining: 1.94s
# 406:	learn: 117462.0903051	total: 721ms	remaining: 1.94s
# 407:	learn: 117354.5749734	total: 722ms	remaining: 1.93s
# 408:	learn: 117116.9775192	total: 724ms	remaining: 1.93s
# 409:	learn: 116943.0648774	total: 726ms	remaining: 1.93s
# 410:	learn: 116879.1661507	total: 727ms	remaining: 1.93s
# 411:	learn: 116796.4510187	total: 729ms	remaining: 1.92s
# 412:	learn: 116388.7204596	total: 730ms	remaining: 1.92s
# 413:	learn: 116360.6033837	total: 732ms	remaining: 1.92s
# 414:	learn: 116198.3033456	total: 733ms	remaining: 1.92s
# 415:	learn: 116120.5526465	total: 735ms	remaining: 1.92s
# 416:	learn: 116071.8232212	total: 737ms	remaining: 1.91s
# 417:	learn: 115905.2251161	total: 738ms	remaining: 1.91s
# 418:	learn: 115703.6261724	total: 740ms	remaining: 1.91s
# 419:	learn: 115616.0974743	total: 741ms	remaining: 1.91s
# 420:	learn: 115442.9857662	total: 743ms	remaining: 1.9s
# 421:	learn: 115099.8183517	total: 744ms	remaining: 1.9s
# 422:	learn: 115074.6391283	total: 746ms	remaining: 1.9s
# 423:	learn: 114924.2410665	total: 747ms	remaining: 1.9s
# 424:	learn: 114823.6942667	total: 749ms	remaining: 1.89s
# 425:	learn: 114808.7757005	total: 751ms	remaining: 1.89s
# 426:	learn: 114753.7421877	total: 752ms	remaining: 1.89s
# 427:	learn: 114712.6444083	total: 754ms	remaining: 1.89s
# 428:	learn: 114669.9753410	total: 755ms	remaining: 1.88s
# 429:	learn: 114652.5172076	total: 757ms	remaining: 1.88s
# 430:	learn: 114582.3193950	total: 758ms	remaining: 1.88s
# 431:	learn: 114263.3532509	total: 760ms	remaining: 1.88s
# 432:	learn: 114241.7525388	total: 761ms	remaining: 1.88s
# 433:	learn: 114071.4827018	total: 763ms	remaining: 1.87s
# 434:	learn: 114064.8686607	total: 764ms	remaining: 1.87s
# 435:	learn: 114063.7784355	total: 766ms	remaining: 1.87s
# 436:	learn: 113993.0582319	total: 767ms	remaining: 1.87s
# 437:	learn: 113746.7024872	total: 769ms	remaining: 1.86s
# 438:	learn: 113732.5522528	total: 770ms	remaining: 1.86s
# 439:	learn: 113666.1586796	total: 772ms	remaining: 1.86s
# 440:	learn: 113551.8414875	total: 773ms	remaining: 1.86s
# 441:	learn: 113207.0754878	total: 775ms	remaining: 1.85s
# 442:	learn: 113002.0485292	total: 776ms	remaining: 1.85s
# 443:	learn: 112861.0743808	total: 778ms	remaining: 1.85s
# 444:	learn: 112756.0670737	total: 779ms	remaining: 1.85s
# 445:	learn: 112709.7429828	total: 781ms	remaining: 1.84s
# 446:	learn: 112675.1122554	total: 782ms	remaining: 1.84s
# 447:	learn: 112295.8025025	total: 784ms	remaining: 1.84s
# 448:	learn: 112088.1874879	total: 785ms	remaining: 1.84s
# 449:	learn: 112029.2170057	total: 787ms	remaining: 1.83s
# 450:	learn: 111893.3226826	total: 788ms	remaining: 1.83s
# 451:	learn: 111723.9801280	total: 790ms	remaining: 1.83s
# 452:	learn: 111678.0189697	total: 791ms	remaining: 1.83s
# 453:	learn: 111601.2057180	total: 793ms	remaining: 1.83s
# 454:	learn: 111574.2742954	total: 794ms	remaining: 1.82s
# 455:	learn: 111489.0890077	total: 796ms	remaining: 1.82s
# 456:	learn: 111418.7162259	total: 798ms	remaining: 1.82s
# 457:	learn: 111292.7532303	total: 800ms	remaining: 1.82s
# 458:	learn: 111240.5653921	total: 801ms	remaining: 1.82s
# 459:	learn: 111198.6311628	total: 803ms	remaining: 1.81s
# 460:	learn: 111196.5994671	total: 804ms	remaining: 1.81s
# 461:	learn: 111116.2204763	total: 806ms	remaining: 1.81s
# 462:	learn: 111059.9606405	total: 808ms	remaining: 1.81s
# 463:	learn: 111003.4851804	total: 810ms	remaining: 1.81s
# 464:	learn: 110929.0710654	total: 812ms	remaining: 1.81s
# 465:	learn: 110858.7081905	total: 813ms	remaining: 1.8s
# 466:	learn: 110823.6764159	total: 815ms	remaining: 1.8s
# 467:	learn: 110755.2367808	total: 816ms	remaining: 1.8s
# 468:	learn: 110684.4680675	total: 818ms	remaining: 1.8s
# 469:	learn: 110658.8870348	total: 819ms	remaining: 1.79s
# 470:	learn: 110611.6080711	total: 821ms	remaining: 1.79s
# 471:	learn: 110585.2805193	total: 823ms	remaining: 1.79s
# 472:	learn: 110288.7569673	total: 825ms	remaining: 1.79s
# 473:	learn: 110205.1527770	total: 827ms	remaining: 1.79s
# 474:	learn: 110104.0791010	total: 828ms	remaining: 1.79s
# 475:	learn: 110086.6257017	total: 830ms	remaining: 1.78s
# 476:	learn: 109921.4600437	total: 831ms	remaining: 1.78s
# 477:	learn: 109772.5461201	total: 833ms	remaining: 1.78s
# 478:	learn: 109676.4726277	total: 834ms	remaining: 1.78s
# 479:	learn: 109491.2334640	total: 836ms	remaining: 1.77s
# 480:	learn: 109368.9470631	total: 837ms	remaining: 1.77s
# 481:	learn: 109111.0444116	total: 839ms	remaining: 1.77s
# 482:	learn: 109050.6248820	total: 841ms	remaining: 1.77s
# 483:	learn: 109024.8246772	total: 842ms	remaining: 1.77s
# 484:	learn: 108818.4070364	total: 844ms	remaining: 1.76s
# 485:	learn: 108688.4583702	total: 845ms	remaining: 1.76s
# 486:	learn: 108635.1942282	total: 847ms	remaining: 1.76s
# 487:	learn: 108519.0996649	total: 848ms	remaining: 1.76s
# 488:	learn: 108433.4819375	total: 850ms	remaining: 1.76s
# 489:	learn: 108255.9254234	total: 851ms	remaining: 1.75s
# 490:	learn: 108107.9893668	total: 853ms	remaining: 1.75s
# 491:	learn: 107738.1096298	total: 854ms	remaining: 1.75s
# 492:	learn: 107736.4257028	total: 856ms	remaining: 1.75s
# 493:	learn: 107668.5820470	total: 858ms	remaining: 1.75s
# 494:	learn: 107581.3541439	total: 859ms	remaining: 1.74s
# 495:	learn: 107500.1754632	total: 861ms	remaining: 1.74s
# 496:	learn: 107417.9111996	total: 862ms	remaining: 1.74s
# 497:	learn: 107398.9753035	total: 864ms	remaining: 1.74s
# 498:	learn: 107118.4512699	total: 865ms	remaining: 1.74s
# 499:	learn: 106833.7993305	total: 867ms	remaining: 1.73s
# 500:	learn: 106699.9499760	total: 869ms	remaining: 1.73s
# 501:	learn: 106626.0157271	total: 870ms	remaining: 1.73s
# 502:	learn: 106609.6209501	total: 872ms	remaining: 1.73s
# 503:	learn: 106346.1063979	total: 873ms	remaining: 1.73s
# 504:	learn: 106330.3998739	total: 875ms	remaining: 1.72s
# 505:	learn: 106325.6820561	total: 877ms	remaining: 1.72s
# 506:	learn: 106135.9043649	total: 879ms	remaining: 1.72s
# 507:	learn: 105764.9890711	total: 881ms	remaining: 1.72s
# 508:	learn: 105749.8782103	total: 882ms	remaining: 1.72s
# 509:	learn: 105668.8372661	total: 884ms	remaining: 1.72s
# 510:	learn: 105623.7673223	total: 885ms	remaining: 1.71s
# 511:	learn: 105610.4340803	total: 887ms	remaining: 1.71s
# 512:	learn: 105484.8001101	total: 889ms	remaining: 1.71s
# 513:	learn: 105427.5908382	total: 890ms	remaining: 1.71s
# 514:	learn: 105298.3646007	total: 892ms	remaining: 1.71s
# 515:	learn: 105183.3304430	total: 894ms	remaining: 1.7s
# 516:	learn: 105141.6516186	total: 895ms	remaining: 1.7s
# 517:	learn: 105137.4450688	total: 897ms	remaining: 1.7s
# 518:	learn: 104868.5439455	total: 898ms	remaining: 1.7s
# 519:	learn: 104633.8736363	total: 900ms	remaining: 1.7s
# 520:	learn: 104565.1693146	total: 901ms	remaining: 1.69s
# 521:	learn: 104525.6162396	total: 903ms	remaining: 1.69s
# 522:	learn: 104446.6793256	total: 905ms	remaining: 1.69s
# 523:	learn: 104405.5976552	total: 906ms	remaining: 1.69s
# 524:	learn: 104242.3890952	total: 908ms	remaining: 1.69s
# 525:	learn: 104130.0691825	total: 910ms	remaining: 1.69s
# 526:	learn: 104124.4182480	total: 912ms	remaining: 1.68s
# 527:	learn: 104040.6723910	total: 914ms	remaining: 1.68s
# 528:	learn: 103984.2753608	total: 915ms	remaining: 1.68s
# 529:	learn: 103968.6853324	total: 917ms	remaining: 1.68s
# 530:	learn: 103887.7396755	total: 918ms	remaining: 1.68s
# 531:	learn: 103838.7892454	total: 920ms	remaining: 1.67s
# 532:	learn: 103827.6834917	total: 922ms	remaining: 1.67s
# 533:	learn: 103798.4078549	total: 923ms	remaining: 1.67s
# 534:	learn: 103775.4329531	total: 925ms	remaining: 1.67s
# 535:	learn: 103707.2604524	total: 926ms	remaining: 1.67s
# 536:	learn: 103704.6430218	total: 928ms	remaining: 1.66s
# 537:	learn: 103703.7297521	total: 929ms	remaining: 1.66s
# 538:	learn: 103576.0969913	total: 930ms	remaining: 1.66s
# 539:	learn: 103527.6954752	total: 932ms	remaining: 1.66s
# 540:	learn: 103490.3568178	total: 934ms	remaining: 1.66s
# 541:	learn: 103205.1393144	total: 936ms	remaining: 1.65s
# 542:	learn: 103095.9214737	total: 938ms	remaining: 1.65s
# 543:	learn: 102948.6106508	total: 939ms	remaining: 1.65s
# 544:	learn: 102915.9056285	total: 941ms	remaining: 1.65s
# 545:	learn: 102879.7133263	total: 942ms	remaining: 1.65s
# 546:	learn: 102823.6464355	total: 944ms	remaining: 1.64s
# 547:	learn: 102685.9663796	total: 945ms	remaining: 1.64s
# 548:	learn: 102635.3303709	total: 947ms	remaining: 1.64s
# 549:	learn: 102596.2339242	total: 949ms	remaining: 1.64s
# 550:	learn: 102533.9727134	total: 950ms	remaining: 1.64s
# 551:	learn: 102311.8122438	total: 952ms	remaining: 1.63s
# 552:	learn: 102215.6421044	total: 953ms	remaining: 1.63s
# 553:	learn: 102183.3775807	total: 955ms	remaining: 1.63s
# 554:	learn: 102125.6909636	total: 956ms	remaining: 1.63s
# 555:	learn: 102009.4725107	total: 958ms	remaining: 1.63s
# 556:	learn: 101980.1119140	total: 959ms	remaining: 1.62s
# 557:	learn: 101837.1968690	total: 962ms	remaining: 1.62s
# 558:	learn: 101820.6334373	total: 963ms	remaining: 1.62s
# 559:	learn: 101792.4371917	total: 965ms	remaining: 1.62s
# 560:	learn: 101702.9254164	total: 966ms	remaining: 1.62s
# 561:	learn: 101572.4226790	total: 968ms	remaining: 1.61s
# 562:	learn: 101568.4589923	total: 969ms	remaining: 1.61s
# 563:	learn: 101561.3740499	total: 971ms	remaining: 1.61s
# 564:	learn: 101559.0380913	total: 972ms	remaining: 1.61s
# 565:	learn: 101544.9078188	total: 974ms	remaining: 1.61s
# 566:	learn: 101502.8151045	total: 976ms	remaining: 1.6s
# 567:	learn: 101456.1402417	total: 978ms	remaining: 1.6s
# 568:	learn: 101424.6717718	total: 980ms	remaining: 1.6s
# 569:	learn: 101410.8042353	total: 981ms	remaining: 1.6s
# 570:	learn: 101408.3335506	total: 983ms	remaining: 1.6s
# 571:	learn: 101383.8926807	total: 984ms	remaining: 1.6s
# 572:	learn: 101215.7035606	total: 986ms	remaining: 1.59s
# 573:	learn: 101171.5899090	total: 987ms	remaining: 1.59s
# 574:	learn: 101126.0097508	total: 989ms	remaining: 1.59s
# 575:	learn: 101104.6153252	total: 991ms	remaining: 1.59s
# 576:	learn: 101049.9245724	total: 992ms	remaining: 1.59s
# 577:	learn: 100889.3863340	total: 998ms	remaining: 1.59s
# 578:	learn: 100823.9137668	total: 1000ms	remaining: 1.59s
# 579:	learn: 100756.6814063	total: 1s	remaining: 1.59s
# 580:	learn: 100731.6772475	total: 1s	remaining: 1.59s
# 581:	learn: 100731.5177385	total: 1s	remaining: 1.58s
# 582:	learn: 100571.7292933	total: 1s	remaining: 1.58s
# 583:	learn: 100398.8062406	total: 1.01s	remaining: 1.58s
# 584:	learn: 100276.1720828	total: 1.01s	remaining: 1.58s
# 585:	learn: 100215.1304873	total: 1.01s	remaining: 1.57s
# 586:	learn: 100204.1443299	total: 1.01s	remaining: 1.57s
# 587:	learn: 100134.7607774	total: 1.01s	remaining: 1.57s
# 588:	learn: 100083.6891749	total: 1.01s	remaining: 1.57s
# 589:	learn: 100063.1211449	total: 1.02s	remaining: 1.57s
# 590:	learn: 99933.8034016	total: 1.02s	remaining: 1.57s
# 591:	learn: 99722.0586448	total: 1.02s	remaining: 1.56s
# 592:	learn: 99643.6640243	total: 1.02s	remaining: 1.56s
# 593:	learn: 99573.9457157	total: 1.02s	remaining: 1.56s
# 594:	learn: 99562.6653645	total: 1.02s	remaining: 1.56s
# 595:	learn: 99558.6650463	total: 1.03s	remaining: 1.56s
# 596:	learn: 99441.7261979	total: 1.03s	remaining: 1.56s
# 597:	learn: 99362.5328705	total: 1.03s	remaining: 1.56s
# 598:	learn: 99333.8571292	total: 1.03s	remaining: 1.55s
# 599:	learn: 99206.0677462	total: 1.03s	remaining: 1.55s
# 600:	learn: 99001.3607996	total: 1.04s	remaining: 1.55s
# 601:	learn: 98985.1690589	total: 1.04s	remaining: 1.55s
# 602:	learn: 98922.8411137	total: 1.04s	remaining: 1.55s
# 603:	learn: 98816.1595440	total: 1.04s	remaining: 1.54s
# 604:	learn: 98694.1200318	total: 1.04s	remaining: 1.54s
# 605:	learn: 98650.3204953	total: 1.04s	remaining: 1.54s
# 606:	learn: 98496.1807573	total: 1.05s	remaining: 1.54s
# 607:	learn: 98452.6473311	total: 1.05s	remaining: 1.54s
# 608:	learn: 98322.6661682	total: 1.05s	remaining: 1.53s
# 609:	learn: 98281.4480836	total: 1.05s	remaining: 1.53s
# 610:	learn: 98267.2613075	total: 1.05s	remaining: 1.53s
# 611:	learn: 98233.9243146	total: 1.05s	remaining: 1.53s
# 612:	learn: 98014.0270508	total: 1.05s	remaining: 1.53s
# 613:	learn: 98007.7895299	total: 1.06s	remaining: 1.52s
# 614:	learn: 97928.8091406	total: 1.06s	remaining: 1.52s
# 615:	learn: 97896.9507020	total: 1.06s	remaining: 1.52s
# 616:	learn: 97709.1099850	total: 1.06s	remaining: 1.52s
# 617:	learn: 97542.6188125	total: 1.06s	remaining: 1.52s
# 618:	learn: 97447.2363965	total: 1.06s	remaining: 1.51s
# 619:	learn: 97391.4310493	total: 1.07s	remaining: 1.51s
# 620:	learn: 97346.1376061	total: 1.07s	remaining: 1.51s
# 621:	learn: 97202.2899543	total: 1.07s	remaining: 1.51s
# 622:	learn: 97009.2804010	total: 1.07s	remaining: 1.51s
# 623:	learn: 96978.9795566	total: 1.07s	remaining: 1.5s
# 624:	learn: 96945.4528754	total: 1.07s	remaining: 1.5s
# 625:	learn: 96915.3567988	total: 1.07s	remaining: 1.5s
# 626:	learn: 96851.7360980	total: 1.08s	remaining: 1.5s
# 627:	learn: 96847.8525252	total: 1.08s	remaining: 1.5s
# 628:	learn: 96846.0208662	total: 1.08s	remaining: 1.5s
# 629:	learn: 96749.1298002	total: 1.08s	remaining: 1.49s
# 630:	learn: 96715.0657472	total: 1.08s	remaining: 1.49s
# 631:	learn: 96602.5174500	total: 1.08s	remaining: 1.49s
# 632:	learn: 96513.9413563	total: 1.09s	remaining: 1.49s
# 633:	learn: 96471.5074874	total: 1.09s	remaining: 1.49s
# 634:	learn: 96179.9490586	total: 1.09s	remaining: 1.48s
# 635:	learn: 96120.3540079	total: 1.09s	remaining: 1.48s
# 636:	learn: 96067.1153000	total: 1.09s	remaining: 1.48s
# 637:	learn: 96043.3955443	total: 1.09s	remaining: 1.48s
# 638:	learn: 95955.0012913	total: 1.1s	remaining: 1.48s
# 639:	learn: 95858.4618466	total: 1.1s	remaining: 1.47s
# 640:	learn: 95852.9352955	total: 1.1s	remaining: 1.47s
# 641:	learn: 95667.2980143	total: 1.1s	remaining: 1.47s
# 642:	learn: 95599.6396971	total: 1.1s	remaining: 1.47s
# 643:	learn: 95450.5007169	total: 1.1s	remaining: 1.47s
# 644:	learn: 95393.9123272	total: 1.1s	remaining: 1.47s
# 645:	learn: 95293.4314983	total: 1.11s	remaining: 1.46s
# 646:	learn: 95214.6041843	total: 1.11s	remaining: 1.46s
# 647:	learn: 95111.0090557	total: 1.11s	remaining: 1.46s
# 648:	learn: 95018.2337520	total: 1.11s	remaining: 1.46s
# 649:	learn: 95007.9738733	total: 1.11s	remaining: 1.46s
# 650:	learn: 94985.2850819	total: 1.11s	remaining: 1.45s
# 651:	learn: 94865.2759512	total: 1.12s	remaining: 1.45s
# 652:	learn: 94775.9161425	total: 1.12s	remaining: 1.45s
# 653:	learn: 94569.9650898	total: 1.12s	remaining: 1.45s
# 654:	learn: 94532.8736860	total: 1.12s	remaining: 1.45s
# 655:	learn: 94440.8135473	total: 1.12s	remaining: 1.44s
# 656:	learn: 94275.3984114	total: 1.12s	remaining: 1.44s
# 657:	learn: 94258.3103712	total: 1.13s	remaining: 1.44s
# 658:	learn: 94161.0430980	total: 1.13s	remaining: 1.44s
# 659:	learn: 94126.6187617	total: 1.13s	remaining: 1.44s
# 660:	learn: 94116.7166165	total: 1.13s	remaining: 1.43s
# 661:	learn: 94027.6809354	total: 1.13s	remaining: 1.43s
# 662:	learn: 94001.9962585	total: 1.13s	remaining: 1.43s
# 663:	learn: 93974.0966581	total: 1.14s	remaining: 1.43s
# 664:	learn: 93964.4751710	total: 1.14s	remaining: 1.43s
# 665:	learn: 93914.7842203	total: 1.14s	remaining: 1.43s
# 666:	learn: 93703.4958659	total: 1.14s	remaining: 1.42s
# 667:	learn: 93656.2191848	total: 1.14s	remaining: 1.42s
# 668:	learn: 93649.0754053	total: 1.14s	remaining: 1.42s
# 669:	learn: 93537.7756646	total: 1.14s	remaining: 1.42s
# 670:	learn: 93501.0826910	total: 1.15s	remaining: 1.42s
# 671:	learn: 93340.6226145	total: 1.15s	remaining: 1.41s
# 672:	learn: 93328.3920056	total: 1.15s	remaining: 1.41s
# 673:	learn: 93327.0352584	total: 1.15s	remaining: 1.41s
# 674:	learn: 93271.9714622	total: 1.15s	remaining: 1.41s
# 675:	learn: 93222.4539539	total: 1.15s	remaining: 1.41s
# 676:	learn: 93162.5934360	total: 1.16s	remaining: 1.4s
# 677:	learn: 93001.4624974	total: 1.16s	remaining: 1.4s
# 678:	learn: 92971.6913227	total: 1.16s	remaining: 1.4s
# 679:	learn: 92965.1045958	total: 1.16s	remaining: 1.4s
# 680:	learn: 92840.5695371	total: 1.16s	remaining: 1.4s
# 681:	learn: 92826.9591773	total: 1.16s	remaining: 1.39s
# 682:	learn: 92795.8070588	total: 1.16s	remaining: 1.39s
# 683:	learn: 92749.2926278	total: 1.17s	remaining: 1.39s
# 684:	learn: 92699.3965202	total: 1.17s	remaining: 1.39s
# 685:	learn: 92591.6137780	total: 1.17s	remaining: 1.39s
# 686:	learn: 92560.8295083	total: 1.17s	remaining: 1.39s
# 687:	learn: 92472.1031801	total: 1.17s	remaining: 1.38s
# 688:	learn: 92400.1406142	total: 1.17s	remaining: 1.38s
# 689:	learn: 92286.7100600	total: 1.18s	remaining: 1.38s
# 690:	learn: 92254.5167753	total: 1.18s	remaining: 1.38s
# 691:	learn: 92133.1775151	total: 1.18s	remaining: 1.38s
# 692:	learn: 91996.2395326	total: 1.18s	remaining: 1.37s
# 693:	learn: 91955.4777733	total: 1.18s	remaining: 1.37s
# 694:	learn: 91928.9287165	total: 1.18s	remaining: 1.37s
# 695:	learn: 91876.2537147	total: 1.18s	remaining: 1.37s
# 696:	learn: 91641.0503947	total: 1.19s	remaining: 1.37s
# 697:	learn: 91560.1094716	total: 1.19s	remaining: 1.36s
# 698:	learn: 91491.7068613	total: 1.19s	remaining: 1.36s
# 699:	learn: 91210.5894566	total: 1.19s	remaining: 1.36s
# 700:	learn: 91177.1169478	total: 1.19s	remaining: 1.36s
# 701:	learn: 91093.0903490	total: 1.19s	remaining: 1.36s
# 702:	learn: 90972.6567583	total: 1.2s	remaining: 1.35s
# 703:	learn: 90920.3467181	total: 1.2s	remaining: 1.35s
# 704:	learn: 90775.0510529	total: 1.2s	remaining: 1.35s
# 705:	learn: 90653.6924277	total: 1.2s	remaining: 1.35s
# 706:	learn: 90627.8412688	total: 1.2s	remaining: 1.35s
# 707:	learn: 90526.8438040	total: 1.21s	remaining: 1.35s
# 708:	learn: 90421.1969860	total: 1.21s	remaining: 1.35s
# 709:	learn: 90390.2043961	total: 1.21s	remaining: 1.34s
# 710:	learn: 90348.8791745	total: 1.21s	remaining: 1.34s
# 711:	learn: 90341.0773126	total: 1.21s	remaining: 1.34s
# 712:	learn: 90295.7849733	total: 1.21s	remaining: 1.34s
# 713:	learn: 90152.9577991	total: 1.21s	remaining: 1.34s
# 714:	learn: 90116.4066790	total: 1.22s	remaining: 1.33s
# 715:	learn: 89983.1400153	total: 1.22s	remaining: 1.33s
# 716:	learn: 89977.1861161	total: 1.22s	remaining: 1.33s
# 717:	learn: 89946.8415070	total: 1.22s	remaining: 1.33s
# 718:	learn: 89822.9459027	total: 1.22s	remaining: 1.33s
# 719:	learn: 89742.3236747	total: 1.22s	remaining: 1.32s
# 720:	learn: 89724.1016042	total: 1.23s	remaining: 1.32s
# 721:	learn: 89715.5348943	total: 1.23s	remaining: 1.32s
# 722:	learn: 89692.5459187	total: 1.23s	remaining: 1.32s
# 723:	learn: 89649.5393048	total: 1.23s	remaining: 1.32s
# 724:	learn: 89627.4219707	total: 1.23s	remaining: 1.32s
# 725:	learn: 89440.8113456	total: 1.23s	remaining: 1.31s
# 726:	learn: 89392.7775110	total: 1.23s	remaining: 1.31s
# 727:	learn: 89293.8777078	total: 1.24s	remaining: 1.31s
# 728:	learn: 89215.0395552	total: 1.24s	remaining: 1.31s
# 729:	learn: 89173.9657288	total: 1.24s	remaining: 1.31s
# 730:	learn: 89117.9745826	total: 1.24s	remaining: 1.3s
# 731:	learn: 89105.2074737	total: 1.24s	remaining: 1.3s
# 732:	learn: 88962.0322703	total: 1.24s	remaining: 1.3s
# 733:	learn: 88863.4181532	total: 1.24s	remaining: 1.3s
# 734:	learn: 88830.2275687	total: 1.25s	remaining: 1.3s
# 735:	learn: 88811.0388619	total: 1.25s	remaining: 1.29s
# 736:	learn: 88686.0370646	total: 1.25s	remaining: 1.29s
# 737:	learn: 88642.7729004	total: 1.25s	remaining: 1.29s
# 738:	learn: 88538.0825388	total: 1.25s	remaining: 1.29s
# 739:	learn: 88444.2314648	total: 1.25s	remaining: 1.29s
# 740:	learn: 88422.3898079	total: 1.25s	remaining: 1.29s
# 741:	learn: 88345.5173002	total: 1.26s	remaining: 1.28s
# 742:	learn: 88262.3888686	total: 1.26s	remaining: 1.28s
# 743:	learn: 88024.7749350	total: 1.26s	remaining: 1.28s
# 744:	learn: 87979.8358435	total: 1.26s	remaining: 1.28s
# 745:	learn: 87944.8088236	total: 1.26s	remaining: 1.28s
# 746:	learn: 87943.2309521	total: 1.26s	remaining: 1.27s
# 747:	learn: 87881.0796729	total: 1.27s	remaining: 1.27s
# 748:	learn: 87856.0769623	total: 1.27s	remaining: 1.27s
# 749:	learn: 87843.8590305	total: 1.27s	remaining: 1.27s
# 750:	learn: 87764.5161299	total: 1.27s	remaining: 1.27s
# 751:	learn: 87724.3362652	total: 1.27s	remaining: 1.26s
# 752:	learn: 87650.0627708	total: 1.27s	remaining: 1.26s
# 753:	learn: 87640.3123517	total: 1.27s	remaining: 1.26s
# 754:	learn: 87562.9350307	total: 1.28s	remaining: 1.26s
# 755:	learn: 87549.8096053	total: 1.28s	remaining: 1.26s
# 756:	learn: 87521.3642677	total: 1.28s	remaining: 1.26s
# 757:	learn: 87496.1776008	total: 1.28s	remaining: 1.25s
# 758:	learn: 87487.4626098	total: 1.28s	remaining: 1.25s
# 759:	learn: 87348.0389272	total: 1.28s	remaining: 1.25s
# 760:	learn: 87332.0650523	total: 1.29s	remaining: 1.25s
# 761:	learn: 87308.8429727	total: 1.29s	remaining: 1.25s
# 762:	learn: 87278.1361947	total: 1.29s	remaining: 1.25s
# 763:	learn: 87245.3961270	total: 1.29s	remaining: 1.24s
# 764:	learn: 87206.5333315	total: 1.29s	remaining: 1.24s
# 765:	learn: 87115.2171126	total: 1.29s	remaining: 1.24s
# 766:	learn: 87015.9742208	total: 1.29s	remaining: 1.24s
# 767:	learn: 86911.1549879	total: 1.3s	remaining: 1.24s
# 768:	learn: 86873.2658317	total: 1.3s	remaining: 1.23s
# 769:	learn: 86861.0197848	total: 1.3s	remaining: 1.23s
# 770:	learn: 86797.5929062	total: 1.3s	remaining: 1.23s
# 771:	learn: 86792.3795860	total: 1.3s	remaining: 1.23s
# 772:	learn: 86731.7591047	total: 1.3s	remaining: 1.23s
# 773:	learn: 86591.8766483	total: 1.3s	remaining: 1.22s
# 774:	learn: 86535.7271011	total: 1.31s	remaining: 1.22s
# 775:	learn: 86395.9043328	total: 1.31s	remaining: 1.22s
# 776:	learn: 86342.9933541	total: 1.31s	remaining: 1.22s
# 777:	learn: 86317.3000716	total: 1.31s	remaining: 1.22s
# 778:	learn: 86100.1377106	total: 1.31s	remaining: 1.22s
# 779:	learn: 86055.2237905	total: 1.31s	remaining: 1.21s
# 780:	learn: 86040.7059711	total: 1.31s	remaining: 1.21s
# 781:	learn: 86027.8842169	total: 1.32s	remaining: 1.21s
# 782:	learn: 86014.5632856	total: 1.32s	remaining: 1.21s
# 783:	learn: 86003.2531828	total: 1.32s	remaining: 1.21s
# 784:	learn: 85946.5057638	total: 1.32s	remaining: 1.2s
# 785:	learn: 85878.6338816	total: 1.32s	remaining: 1.2s
# 786:	learn: 85861.7341616	total: 1.32s	remaining: 1.2s
# 787:	learn: 85852.0955789	total: 1.33s	remaining: 1.2s
# 788:	learn: 85834.8659685	total: 1.33s	remaining: 1.2s
# 789:	learn: 85747.2563664	total: 1.33s	remaining: 1.19s
# 790:	learn: 85744.8272169	total: 1.33s	remaining: 1.19s
# 791:	learn: 85738.5725163	total: 1.33s	remaining: 1.19s
# 792:	learn: 85718.9754577	total: 1.33s	remaining: 1.19s
# 793:	learn: 85712.1680371	total: 1.33s	remaining: 1.19s
# 794:	learn: 85632.8936522	total: 1.34s	remaining: 1.19s
# 795:	learn: 85457.8207898	total: 1.34s	remaining: 1.18s
# 796:	learn: 85435.7279301	total: 1.34s	remaining: 1.18s
# 797:	learn: 85430.1086914	total: 1.34s	remaining: 1.18s
# 798:	learn: 85301.6489227	total: 1.34s	remaining: 1.18s
# 799:	learn: 85270.6347431	total: 1.34s	remaining: 1.18s
# 800:	learn: 85250.6658810	total: 1.34s	remaining: 1.17s
# 801:	learn: 85218.3322314	total: 1.35s	remaining: 1.17s
# 802:	learn: 85105.9059901	total: 1.35s	remaining: 1.17s
# 803:	learn: 85026.9994378	total: 1.35s	remaining: 1.17s
# 804:	learn: 84946.6497989	total: 1.35s	remaining: 1.17s
# 805:	learn: 84876.2702823	total: 1.35s	remaining: 1.17s
# 806:	learn: 84842.1005518	total: 1.35s	remaining: 1.16s
# 807:	learn: 84825.6793099	total: 1.36s	remaining: 1.16s
# 808:	learn: 84753.1480259	total: 1.36s	remaining: 1.16s
# 809:	learn: 84728.4359048	total: 1.36s	remaining: 1.16s
# 810:	learn: 84691.4331509	total: 1.36s	remaining: 1.16s
# 811:	learn: 84653.3854625	total: 1.36s	remaining: 1.16s
# 812:	learn: 84613.2555044	total: 1.36s	remaining: 1.15s
# 813:	learn: 84592.6494279	total: 1.37s	remaining: 1.15s
# 814:	learn: 84561.7633248	total: 1.37s	remaining: 1.15s
# 815:	learn: 84552.2487993	total: 1.37s	remaining: 1.15s
# 816:	learn: 84533.5096797	total: 1.37s	remaining: 1.15s
# 817:	learn: 84427.2958859	total: 1.37s	remaining: 1.14s
# 818:	learn: 84400.4277233	total: 1.37s	remaining: 1.14s
# 819:	learn: 84385.1231946	total: 1.38s	remaining: 1.14s
# 820:	learn: 84323.0230583	total: 1.38s	remaining: 1.14s
# 821:	learn: 84245.8853933	total: 1.38s	remaining: 1.14s
# 822:	learn: 84147.7100142	total: 1.38s	remaining: 1.14s
# 823:	learn: 84097.9794647	total: 1.38s	remaining: 1.13s
# 824:	learn: 84039.5029133	total: 1.38s	remaining: 1.13s
# 825:	learn: 83955.5173638	total: 1.39s	remaining: 1.13s
# 826:	learn: 83934.8409643	total: 1.39s	remaining: 1.13s
# 827:	learn: 83842.2203378	total: 1.39s	remaining: 1.13s
# 828:	learn: 83744.7954670	total: 1.39s	remaining: 1.13s
# 829:	learn: 83734.3707334	total: 1.39s	remaining: 1.12s
# 830:	learn: 83698.5402085	total: 1.39s	remaining: 1.12s
# 831:	learn: 83681.2940113	total: 1.4s	remaining: 1.12s
# 832:	learn: 83636.8618566	total: 1.4s	remaining: 1.12s
# 833:	learn: 83536.8559430	total: 1.4s	remaining: 1.12s
# 834:	learn: 83454.4079241	total: 1.4s	remaining: 1.11s
# 835:	learn: 83400.9233448	total: 1.4s	remaining: 1.11s
# 836:	learn: 83364.7258860	total: 1.4s	remaining: 1.11s
# 837:	learn: 83358.7139440	total: 1.4s	remaining: 1.11s
# 838:	learn: 83319.1551726	total: 1.41s	remaining: 1.11s
# 839:	learn: 83231.2301585	total: 1.41s	remaining: 1.11s
# 840:	learn: 83194.2108744	total: 1.41s	remaining: 1.1s
# 841:	learn: 83108.3257340	total: 1.41s	remaining: 1.1s
# 842:	learn: 83033.2856653	total: 1.41s	remaining: 1.1s
# 843:	learn: 82939.9844488	total: 1.41s	remaining: 1.1s
# 844:	learn: 82740.3132499	total: 1.42s	remaining: 1.1s
# 845:	learn: 82713.0091786	total: 1.42s	remaining: 1.09s
# 846:	learn: 82695.8134308	total: 1.42s	remaining: 1.09s
# 847:	learn: 82685.6809535	total: 1.42s	remaining: 1.09s
# 848:	learn: 82653.0418767	total: 1.42s	remaining: 1.09s
# 849:	learn: 82605.2161772	total: 1.42s	remaining: 1.09s
# ...
# 1220:	learn: 70482.8171460	total: 2.01s	remaining: 460ms
# 1221:	learn: 70477.7051063	total: 2.01s	remaining: 458ms
# 1222:	learn: 70464.5977728	total: 2.02s	remaining: 457ms
# 1223:	learn: 70421.1285975	total: 2.02s	remaining: 455ms
# 1224:	learn: 70373.7392483	total: 2.02s	remaining: 453ms
# 1225:	learn: 70365.8640443	total: 2.02s	remaining: 452ms
# 1226:	learn: 70337.0081740	total: 2.02s	remaining: 450ms
# 1227:	learn: 70309.1204906	total: 2.02s	remaining: 448ms
# 1228:	learn: 70288.9572184	total: 2.02s	remaining: 447ms
# 1229:	learn: 70267.2337562	total: 2.03s	remaining: 445ms
# 1230:	learn: 70264.4229412	total: 2.03s	remaining: 443ms
# 1231:	learn: 70241.0810628	total: 2.03s	remaining: 442ms
# 1232:	learn: 70221.3163535	total: 2.03s	remaining: 440ms
# 1233:	learn: 70190.0453730	total: 2.03s	remaining: 438ms
# 1234:	learn: 70156.0958700	total: 2.03s	remaining: 437ms
# 1235:	learn: 70148.6430344	total: 2.04s	remaining: 435ms
# 1236:	learn: 70140.5732388	total: 2.04s	remaining: 433ms
# 1237:	learn: 70133.9942085	total: 2.04s	remaining: 432ms
# 1238:	learn: 70125.9184441	total: 2.04s	remaining: 430ms
# 1239:	learn: 70095.9002737	total: 2.04s	remaining: 428ms
# 1240:	learn: 70085.8969521	total: 2.04s	remaining: 426ms
# 1241:	learn: 70080.9620444	total: 2.04s	remaining: 425ms
# 1242:	learn: 70038.1283822	total: 2.05s	remaining: 423ms
# 1243:	learn: 70018.9019227	total: 2.05s	remaining: 421ms
# 1244:	learn: 70013.6488220	total: 2.05s	remaining: 420ms
# 1245:	learn: 70005.7434796	total: 2.05s	remaining: 418ms
# 1246:	learn: 69991.1068703	total: 2.05s	remaining: 416ms
# 1247:	learn: 69933.5772067	total: 2.05s	remaining: 415ms
# 1248:	learn: 69912.6638699	total: 2.06s	remaining: 413ms
# 1249:	learn: 69889.2518461	total: 2.06s	remaining: 411ms
# 1250:	learn: 69870.9983089	total: 2.06s	remaining: 410ms
# 1251:	learn: 69855.2288041	total: 2.06s	remaining: 408ms
# 1252:	learn: 69836.1763988	total: 2.06s	remaining: 406ms
# 1253:	learn: 69827.4322209	total: 2.06s	remaining: 405ms
# 1254:	learn: 69820.8254834	total: 2.06s	remaining: 403ms
# 1255:	learn: 69815.2746193	total: 2.06s	remaining: 401ms
# 1256:	learn: 69810.4054161	total: 2.07s	remaining: 400ms
# 1257:	learn: 69798.5831052	total: 2.07s	remaining: 398ms
# 1258:	learn: 69732.0067463	total: 2.07s	remaining: 396ms
# 1259:	learn: 69710.4320523	total: 2.07s	remaining: 395ms
# 1260:	learn: 69651.6679573	total: 2.07s	remaining: 393ms
# 1261:	learn: 69612.1359724	total: 2.07s	remaining: 391ms
# 1262:	learn: 69591.7222196	total: 2.08s	remaining: 390ms
# 1263:	learn: 69564.6719944	total: 2.08s	remaining: 388ms
# 1264:	learn: 69557.3550960	total: 2.08s	remaining: 386ms
# 1265:	learn: 69541.6999276	total: 2.08s	remaining: 385ms
# 1266:	learn: 69523.5265075	total: 2.08s	remaining: 383ms
# 1267:	learn: 69509.9685766	total: 2.08s	remaining: 381ms
# 1268:	learn: 69476.6146070	total: 2.08s	remaining: 380ms
# 1269:	learn: 69452.5548604	total: 2.09s	remaining: 378ms
# 1270:	learn: 69437.2409297	total: 2.09s	remaining: 376ms
# 1271:	learn: 69425.8554794	total: 2.09s	remaining: 375ms
# 1272:	learn: 69414.1147817	total: 2.09s	remaining: 373ms
# 1273:	learn: 69385.5467976	total: 2.09s	remaining: 371ms
# 1274:	learn: 69371.6483345	total: 2.09s	remaining: 370ms
# 1275:	learn: 69321.4970286	total: 2.1s	remaining: 368ms
# 1276:	learn: 69315.8670072	total: 2.1s	remaining: 366ms
# 1277:	learn: 69241.8868937	total: 2.1s	remaining: 365ms
# 1278:	learn: 69209.4171272	total: 2.1s	remaining: 363ms
# 1279:	learn: 69197.3115086	total: 2.1s	remaining: 361ms
# 1280:	learn: 69159.1202510	total: 2.1s	remaining: 360ms
# 1281:	learn: 69120.4101570	total: 2.1s	remaining: 358ms
# 1282:	learn: 69071.2703038	total: 2.11s	remaining: 356ms
# 1283:	learn: 69053.8513292	total: 2.11s	remaining: 355ms
# 1284:	learn: 69036.9728834	total: 2.11s	remaining: 353ms
# 1285:	learn: 68949.6472865	total: 2.11s	remaining: 351ms
# 1286:	learn: 68934.4946692	total: 2.11s	remaining: 350ms
# 1287:	learn: 68924.5667692	total: 2.11s	remaining: 348ms
# 1288:	learn: 68903.1849960	total: 2.12s	remaining: 346ms
# 1289:	learn: 68836.1097636	total: 2.12s	remaining: 345ms
# 1290:	learn: 68827.7757156	total: 2.12s	remaining: 343ms
# 1291:	learn: 68785.4037301	total: 2.12s	remaining: 341ms
# 1292:	learn: 68773.0333721	total: 2.12s	remaining: 340ms
# 1293:	learn: 68753.0138231	total: 2.12s	remaining: 338ms
# 1294:	learn: 68748.8608208	total: 2.12s	remaining: 336ms
# 1295:	learn: 68740.7029553	total: 2.13s	remaining: 335ms
# 1296:	learn: 68735.2046634	total: 2.13s	remaining: 333ms
# 1297:	learn: 68725.4397657	total: 2.13s	remaining: 331ms
# 1298:	learn: 68710.8237114	total: 2.13s	remaining: 330ms
# 1299:	learn: 68678.3219775	total: 2.13s	remaining: 328ms
# 1300:	learn: 68672.8658734	total: 2.13s	remaining: 326ms
# 1301:	learn: 68633.3474843	total: 2.13s	remaining: 325ms
# 1302:	learn: 68595.2749061	total: 2.14s	remaining: 323ms
# 1303:	learn: 68578.4604105	total: 2.14s	remaining: 321ms
# 1304:	learn: 68566.3186137	total: 2.14s	remaining: 320ms
# 1305:	learn: 68544.0187364	total: 2.14s	remaining: 318ms
# 1306:	learn: 68505.0931309	total: 2.14s	remaining: 316ms
# 1307:	learn: 68502.5451419	total: 2.14s	remaining: 315ms
# 1308:	learn: 68498.3507922	total: 2.15s	remaining: 313ms
# 1309:	learn: 68490.9171145	total: 2.15s	remaining: 311ms
# 1310:	learn: 68487.0830931	total: 2.15s	remaining: 310ms
# 1311:	learn: 68432.0006511	total: 2.15s	remaining: 309ms
# 1312:	learn: 68428.4060056	total: 2.15s	remaining: 307ms
# 1313:	learn: 68424.4363419	total: 2.16s	remaining: 305ms
# 1314:	learn: 68328.6633869	total: 2.16s	remaining: 304ms
# 1315:	learn: 68321.3451381	total: 2.16s	remaining: 302ms
# 1316:	learn: 68315.2295063	total: 2.16s	remaining: 300ms
# 1317:	learn: 68281.5988340	total: 2.16s	remaining: 299ms
# 1318:	learn: 68270.2742062	total: 2.17s	remaining: 297ms
# 1319:	learn: 68233.1490518	total: 2.17s	remaining: 296ms
# 1320:	learn: 68230.4926945	total: 2.17s	remaining: 294ms
# 1321:	learn: 68204.8565428	total: 2.17s	remaining: 292ms
# 1322:	learn: 68193.3382654	total: 2.17s	remaining: 291ms
# 1323:	learn: 68176.9062010	total: 2.17s	remaining: 289ms
# 1324:	learn: 68157.2148930	total: 2.17s	remaining: 287ms
# 1325:	learn: 68150.1967708	total: 2.18s	remaining: 286ms
# 1326:	learn: 68135.0190080	total: 2.18s	remaining: 284ms
# 1327:	learn: 68126.9010281	total: 2.18s	remaining: 282ms
# 1328:	learn: 68072.9868392	total: 2.18s	remaining: 281ms
# 1329:	learn: 68016.1169954	total: 2.18s	remaining: 279ms
# 1330:	learn: 67969.2820381	total: 2.18s	remaining: 277ms
# 1331:	learn: 67969.1534308	total: 2.19s	remaining: 276ms
# 1332:	learn: 67922.8906579	total: 2.19s	remaining: 274ms
# 1333:	learn: 67919.2838609	total: 2.19s	remaining: 272ms
# 1334:	learn: 67893.2770373	total: 2.19s	remaining: 271ms
# 1335:	learn: 67883.2922578	total: 2.19s	remaining: 269ms
# 1336:	learn: 67882.6545916	total: 2.19s	remaining: 267ms
# 1337:	learn: 67843.4567098	total: 2.19s	remaining: 266ms
# 1338:	learn: 67834.0002745	total: 2.2s	remaining: 264ms
# 1339:	learn: 67824.4189165	total: 2.2s	remaining: 262ms
# 1340:	learn: 67794.7912917	total: 2.2s	remaining: 261ms
# 1341:	learn: 67787.2628046	total: 2.2s	remaining: 259ms
# 1342:	learn: 67772.5269055	total: 2.2s	remaining: 257ms
# 1343:	learn: 67757.4941209	total: 2.2s	remaining: 256ms
# 1344:	learn: 67755.2708950	total: 2.21s	remaining: 254ms
# 1345:	learn: 67722.8922656	total: 2.21s	remaining: 253ms
# 1346:	learn: 67639.9789932	total: 2.21s	remaining: 251ms
# 1347:	learn: 67628.5743696	total: 2.21s	remaining: 249ms
# 1348:	learn: 67584.3970248	total: 2.21s	remaining: 248ms
# 1349:	learn: 67503.5817647	total: 2.21s	remaining: 246ms
# 1350:	learn: 67494.6906458	total: 2.21s	remaining: 244ms
# 1351:	learn: 67490.8274201	total: 2.22s	remaining: 243ms
# 1352:	learn: 67462.9460610	total: 2.22s	remaining: 241ms
# 1353:	learn: 67444.6032828	total: 2.22s	remaining: 239ms
# 1354:	learn: 67432.8945881	total: 2.22s	remaining: 238ms
# 1355:	learn: 67408.2197828	total: 2.22s	remaining: 236ms
# 1356:	learn: 67402.2629107	total: 2.22s	remaining: 234ms
# 1357:	learn: 67386.6297321	total: 2.23s	remaining: 233ms
# 1358:	learn: 67378.4144053	total: 2.23s	remaining: 231ms
# 1359:	learn: 67369.7578860	total: 2.23s	remaining: 229ms
# 1360:	learn: 67295.2444105	total: 2.23s	remaining: 228ms
# 1361:	learn: 67259.8791077	total: 2.23s	remaining: 226ms
# 1362:	learn: 67253.9508660	total: 2.23s	remaining: 224ms
# 1363:	learn: 67246.1767279	total: 2.23s	remaining: 223ms
# 1364:	learn: 67219.6478777	total: 2.24s	remaining: 221ms
# 1365:	learn: 67207.5856905	total: 2.24s	remaining: 220ms
# 1366:	learn: 67184.3101466	total: 2.24s	remaining: 218ms
# 1367:	learn: 67164.5356836	total: 2.24s	remaining: 216ms
# 1368:	learn: 67125.0553403	total: 2.24s	remaining: 215ms
# 1369:	learn: 67105.3405157	total: 2.24s	remaining: 213ms
# 1370:	learn: 67084.5264269	total: 2.25s	remaining: 211ms
# 1371:	learn: 67077.2325075	total: 2.25s	remaining: 210ms
# 1372:	learn: 67063.3764870	total: 2.25s	remaining: 208ms
# 1373:	learn: 67048.3325731	total: 2.25s	remaining: 206ms
# 1374:	learn: 67010.1366779	total: 2.25s	remaining: 205ms
# 1375:	learn: 67006.1409988	total: 2.25s	remaining: 203ms
# 1376:	learn: 66993.5813697	total: 2.25s	remaining: 201ms
# 1377:	learn: 66958.7914879	total: 2.26s	remaining: 200ms
# 1378:	learn: 66942.0294886	total: 2.26s	remaining: 198ms
# 1379:	learn: 66911.9225202	total: 2.26s	remaining: 196ms
# 1380:	learn: 66904.7155140	total: 2.26s	remaining: 195ms
# 1381:	learn: 66895.9955859	total: 2.26s	remaining: 193ms
# 1382:	learn: 66880.6604629	total: 2.26s	remaining: 191ms
# 1383:	learn: 66837.9265494	total: 2.26s	remaining: 190ms
# 1384:	learn: 66784.5308203	total: 2.27s	remaining: 188ms
# 1385:	learn: 66709.8724849	total: 2.27s	remaining: 187ms
# 1386:	learn: 66702.5855655	total: 2.27s	remaining: 185ms
# 1387:	learn: 66627.4983020	total: 2.27s	remaining: 183ms
# 1388:	learn: 66576.8580610	total: 2.27s	remaining: 182ms
# 1389:	learn: 66575.6358528	total: 2.27s	remaining: 180ms
# 1390:	learn: 66560.7921857	total: 2.27s	remaining: 178ms
# 1391:	learn: 66519.4713056	total: 2.28s	remaining: 177ms
# 1392:	learn: 66518.6179885	total: 2.28s	remaining: 175ms
# 1393:	learn: 66458.8378578	total: 2.28s	remaining: 173ms
# 1394:	learn: 66429.8717388	total: 2.28s	remaining: 172ms
# 1395:	learn: 66422.0064726	total: 2.28s	remaining: 170ms
# 1396:	learn: 66395.8991776	total: 2.28s	remaining: 168ms
# 1397:	learn: 66354.7291502	total: 2.29s	remaining: 167ms
# 1398:	learn: 66345.0038325	total: 2.29s	remaining: 165ms
# 1399:	learn: 66341.3288147	total: 2.29s	remaining: 163ms
# 1400:	learn: 66341.1713726	total: 2.29s	remaining: 162ms
# 1401:	learn: 66292.1481201	total: 2.29s	remaining: 160ms
# 1402:	learn: 66225.6876169	total: 2.29s	remaining: 159ms
# 1403:	learn: 66210.1620568	total: 2.29s	remaining: 157ms
# 1404:	learn: 66203.6433846	total: 2.3s	remaining: 155ms
# 1405:	learn: 66196.8694066	total: 2.3s	remaining: 154ms
# 1406:	learn: 66193.3572950	total: 2.3s	remaining: 152ms
# 1407:	learn: 66164.3573107	total: 2.3s	remaining: 150ms
# 1408:	learn: 66159.4939965	total: 2.3s	remaining: 149ms
# 1409:	learn: 66148.2569896	total: 2.3s	remaining: 147ms
# 1410:	learn: 66108.1558426	total: 2.31s	remaining: 145ms
# 1411:	learn: 66102.4472641	total: 2.31s	remaining: 144ms
# 1412:	learn: 66090.4798355	total: 2.31s	remaining: 142ms
# 1413:	learn: 66061.6836963	total: 2.31s	remaining: 141ms
# 1414:	learn: 66050.9716345	total: 2.31s	remaining: 139ms
# 1415:	learn: 66040.7410796	total: 2.31s	remaining: 137ms
# 1416:	learn: 66035.8090333	total: 2.31s	remaining: 136ms
# 1417:	learn: 66015.1613403	total: 2.32s	remaining: 134ms
# 1418:	learn: 66004.3662032	total: 2.32s	remaining: 132ms
# 1419:	learn: 65950.4275044	total: 2.32s	remaining: 131ms
# 1420:	learn: 65928.4883195	total: 2.32s	remaining: 129ms
# 1421:	learn: 65928.4198625	total: 2.32s	remaining: 127ms
# 1422:	learn: 65863.8320937	total: 2.32s	remaining: 126ms
# 1423:	learn: 65858.6896842	total: 2.33s	remaining: 124ms
# 1424:	learn: 65848.9691259	total: 2.33s	remaining: 123ms
# 1425:	learn: 65838.5056709	total: 2.33s	remaining: 121ms
# 1426:	learn: 65832.2307689	total: 2.33s	remaining: 119ms
# 1427:	learn: 65806.8960820	total: 2.33s	remaining: 118ms
# 1428:	learn: 65790.8107185	total: 2.33s	remaining: 116ms
# 1429:	learn: 65780.0727059	total: 2.33s	remaining: 114ms
# 1430:	learn: 65771.9415164	total: 2.34s	remaining: 113ms
# 1431:	learn: 65767.7085538	total: 2.34s	remaining: 111ms
# 1432:	learn: 65757.1695276	total: 2.34s	remaining: 109ms
# 1433:	learn: 65744.5614663	total: 2.34s	remaining: 108ms
# 1434:	learn: 65674.3259141	total: 2.34s	remaining: 106ms
# 1435:	learn: 65672.4781448	total: 2.35s	remaining: 105ms
# 1436:	learn: 65645.5558269	total: 2.35s	remaining: 103ms
# 1437:	learn: 65613.7528800	total: 2.35s	remaining: 101ms
# 1438:	learn: 65612.3592214	total: 2.35s	remaining: 99.6ms
# 1439:	learn: 65596.6777053	total: 2.35s	remaining: 98ms
# 1440:	learn: 65547.4297286	total: 2.35s	remaining: 96.3ms
# 1441:	learn: 65539.5205295	total: 2.35s	remaining: 94.7ms
# 1442:	learn: 65533.6472738	total: 2.36s	remaining: 93.1ms
# 1443:	learn: 65513.7267201	total: 2.36s	remaining: 91.4ms
# 1444:	learn: 65486.2564991	total: 2.36s	remaining: 89.8ms
# 1445:	learn: 65482.9063516	total: 2.36s	remaining: 88.2ms
# 1446:	learn: 65446.3467079	total: 2.36s	remaining: 86.5ms
# 1447:	learn: 65434.4513249	total: 2.36s	remaining: 84.9ms
# 1448:	learn: 65416.4104405	total: 2.37s	remaining: 83.3ms
# 1449:	learn: 65412.7570929	total: 2.37s	remaining: 81.6ms
# 1450:	learn: 65337.5672697	total: 2.37s	remaining: 80ms
# 1451:	learn: 65315.9817889	total: 2.37s	remaining: 78.3ms
# 1452:	learn: 65305.4068232	total: 2.37s	remaining: 76.7ms
# 1453:	learn: 65301.0197319	total: 2.37s	remaining: 75.1ms
# 1454:	learn: 65228.2239761	total: 2.37s	remaining: 73.4ms
# 1455:	learn: 65223.5296927	total: 2.38s	remaining: 71.8ms
# 1456:	learn: 65158.4117957	total: 2.38s	remaining: 70.2ms
# 1457:	learn: 65116.9204474	total: 2.38s	remaining: 68.5ms
# 1458:	learn: 65112.3677029	total: 2.38s	remaining: 66.9ms
# 1459:	learn: 65100.7381864	total: 2.38s	remaining: 65.3ms
# 1460:	learn: 65058.6907699	total: 2.38s	remaining: 63.6ms
# 1461:	learn: 65042.0026173	total: 2.38s	remaining: 62ms
# 1462:	learn: 65041.8417376	total: 2.39s	remaining: 60.4ms
# 1463:	learn: 65041.7383066	total: 2.39s	remaining: 58.7ms
# 1464:	learn: 65003.0397098	total: 2.39s	remaining: 57.1ms
# 1465:	learn: 64986.7732167	total: 2.39s	remaining: 55.5ms
# 1466:	learn: 64978.7053949	total: 2.39s	remaining: 53.8ms
# 1467:	learn: 64975.5767954	total: 2.39s	remaining: 52.2ms
# 1468:	learn: 64965.7086649	total: 2.4s	remaining: 50.6ms
# 1469:	learn: 64963.1950885	total: 2.4s	remaining: 48.9ms
# 1470:	learn: 64956.6081890	total: 2.4s	remaining: 47.3ms
# 1471:	learn: 64850.1708927	total: 2.4s	remaining: 45.7ms
# 1472:	learn: 64844.8932511	total: 2.4s	remaining: 44ms
# 1473:	learn: 64840.2279480	total: 2.4s	remaining: 42.4ms
# 1474:	learn: 64826.9553701	total: 2.4s	remaining: 40.8ms
# 1475:	learn: 64804.1549474	total: 2.41s	remaining: 39.1ms
# 1476:	learn: 64792.3578957	total: 2.41s	remaining: 37.5ms
# 1477:	learn: 64759.3023773	total: 2.41s	remaining: 35.9ms
# 1478:	learn: 64733.1091940	total: 2.41s	remaining: 34.2ms
# 1479:	learn: 64726.8984789	total: 2.41s	remaining: 32.6ms
# 1480:	learn: 64724.3831358	total: 2.42s	remaining: 31ms
# 1481:	learn: 64717.4392077	total: 2.42s	remaining: 29.4ms
# 1482:	learn: 64698.6125619	total: 2.42s	remaining: 27.7ms
# 1483:	learn: 64686.2370750	total: 2.42s	remaining: 26.1ms
# 1484:	learn: 64637.3134873	total: 2.42s	remaining: 24.5ms
# 1485:	learn: 64588.7732002	total: 2.42s	remaining: 22.8ms
# 1486:	learn: 64546.4160131	total: 2.42s	remaining: 21.2ms
# 1487:	learn: 64514.8197889	total: 2.43s	remaining: 19.6ms
# 1488:	learn: 64457.3868095	total: 2.43s	remaining: 17.9ms
# 1489:	learn: 64429.7986020	total: 2.43s	remaining: 16.3ms
# 1490:	learn: 64405.3757695	total: 2.43s	remaining: 14.7ms
# 1491:	learn: 64380.8319213	total: 2.43s	remaining: 13ms
# 1492:	learn: 64373.3339658	total: 2.43s	remaining: 11.4ms
# 1493:	learn: 64356.6506568	total: 2.44s	remaining: 9.78ms
# 1494:	learn: 64347.9538784	total: 2.44s	remaining: 8.15ms
# 1495:	learn: 64336.3146569	total: 2.44s	remaining: 6.52ms
# 1496:	learn: 64328.4389090	total: 2.44s	remaining: 4.89ms
# 1497:	learn: 64302.5257205	total: 2.44s	remaining: 3.26ms
# 1498:	learn: 64300.6388205	total: 2.44s	remaining: 1.63ms
# 1499:	learn: 64291.3614706	total: 2.44s	remaining: 0us

# %%
sub['value'] = cat_clf.predict(test_X.values)
print(sub)
# Out:
#          id         value
# 0         1  7.937903e+07
# 1         2  8.783381e+07
# 2         4  7.449537e+07
# 3         5  7.728491e+07
# 4         6  6.150963e+07
# ...     ...           ...
# 3823  16924  6.818762e+04
# 3824  16929  5.009635e+04
# 3825  16932  5.017469e+04
# 3826  16937  6.337740e+04
# 3827  16943  6.797491e+04
#
# [3828 rows x 2 columns]

# %%
sub.to_csv('./sub/pre/cat2.csv', index=False)

# %%
# lgb_clf = lgb.LGBMRegressor(**params, early_stoppong_rounds = 100)

# xgb_clf = xgb.XGBRegressor(
#             **params_fx,
#             early_stoppong_rounds = 100         
#     )

# cat_clf = cat.CatBoostRegressor(random_seed=42, n_estimators=3000, early_stopping_rounds=50)

rf1 = RandomForestRegressor(n_estimators=200,
                                max_depth=13, 
                                max_features='sqrt', 
                                random_state=21)

rf2 = RandomForestRegressor(n_estimators=150,
                                max_depth=9, 
                                max_features='sqrt', 
                                random_state=12)

pca = PCA(15, random_state=42)

lr = LinearRegression()
els = ElasticNet(random_state=42, l1_ratio=1)
las = Lasso(random_state=21)

hl = HuberRegressor()

svr = SVR()

adb = AdaBoostRegressor(hl,
                        random_state=12,
                       n_estimators=500,
                       learning_rate=0.01)

pca = PCA(9)

test_sets = [lr, els, las, hl, svr]

# %%
for mo in test_sets:
    print(-1*np.mean(cross_val_score(mo, train_X, target, scoring='neg_mean_squared_error', cv=5)))

# %%
train_X.shape

# %%
_models = [[lgb_clf, xgb_clf, cat_clf, pca],
          [rf1]
         ]

# %%
model = StackNetRegressor(_models, 
                           metric="rmse", 
                           folds=4,
                           restacking=False,
                           random_state=42,
                           n_jobs=-1, 
                           verbose=1)

model.fit(train_X.values, target)
# Out:
# ====================== Start of Level 0 ======================
# Input Dimensionality 12 at Level 0
# 4 models included in Level 0
# Fold 1/4 , model 0 , rmse===984184.357971
# Fold 1/4 , model 1 , rmse===994459.407656
# Fold 1/4 , model 2 , rmse===1063365.839201
# =========== end of fold 1 in level 0 ===========
# Fold 2/4 , model 0 , rmse===759628.534109
# Fold 2/4 , model 1 , rmse===813047.539983
# Fold 2/4 , model 2 , rmse===581047.819310
# =========== end of fold 2 in level 0 ===========
# Fold 3/4 , model 0 , rmse===671014.185862
# Fold 3/4 , model 1 , rmse===622677.268465
# Fold 3/4 , model 2 , rmse===469304.804220
# =========== end of fold 3 in level 0 ===========
# Fold 4/4 , model 0 , rmse===814473.872531
# Fold 4/4 , model 1 , rmse===896291.803596
# Fold 4/4 , model 2 , rmse===688581.270281
# =========== end of fold 4 in level 0 ===========
# Output dimensionality of level 0 is 12
# ====================== End of Level 0 ======================
#  level 0 lasted 38.628135 seconds
# ====================== Start of Level 1 ======================
# Input Dimensionality 12 at Level 1
# 1 models included in Level 1
# Fold 1/4 , model 0 , rmse===1326673.748070
# =========== end of fold 1 in level 1 ===========
# Fold 2/4 , model 0 , rmse===637918.336281
# =========== end of fold 2 in level 1 ===========
# Fold 3/4 , model 0 , rmse===618550.965952
# =========== end of fold 3 in level 1 ===========
# Fold 4/4 , model 0 , rmse===641572.290933
# =========== end of fold 4 in level 1 ===========
# Output dimensionality of level 1 is 1
# ====================== End of Level 1 ======================
#  level 1 lasted 31.741575 seconds
# ====================== End of fit ======================
#  fit() lasted 70.370738 seconds

# %%
sub['value'] = model.predict(test_X.values)
print(sub)
# Out:
# ====================== Start of Level 0 ======================
# 1 estimators included in Level 0
# ====================== Start of Level 1 ======================
# 1 estimators included in Level 1
#          id         value
# 0         1  7.036750e+07
# 1         2  7.642062e+07
# 2         4  6.587000e+07
# 3         5  7.133812e+07
# 4         6  5.805750e+07
# ...     ...           ...
# 3823  16924  7.001611e+04
# 3824  16929  6.318696e+04
# 3825  16932  6.579765e+04
# 3826  16937  7.280371e+04
# 3827  16943  6.909499e+04
#
# [3828 rows x 2 columns]

# %%
sub.to_csv('./sub/pre/stk3.csv', index=False)

# %%
##################

# %%
km = KMeans(random_state=42, n_clusters=10).fit(train_X)

tr_km = pd.get_dummies(km.predict(train_X))
te_km = pd.get_dummies(km.predict(test_X))

# %%
k1 = model.predict_up_to(train_X.values)
k2 = model.predict_up_to(test_X.values)
# Out:
# ====================== Start of Level 0 ======================
# 1 estimators included in Level 0
# (8932, 12)
# ====================== Start of Level 1 ======================
# 1 estimators included in Level 1
# (8932, 1)
# ====================== Start of Level 0 ======================
# 1 estimators included in Level 0
# (3828, 12)
# ====================== Start of Level 1 ======================
# 1 estimators included in Level 1
# (3828, 1)

# %%
new_tr_X = k1[0]
new_te_X = k2[0]

# %%
new_merge = pd.DataFrame(np.concatenate([new_tr_X, new_te_X]))

k = (new_merge - np.mean(new_merge)) / np.std(new_merge)

# %%
new_tr_X = k.values[0:len(new_tr_X)]
new_te_X = k.values[len(new_tr_X):]

# %%
t = np.log(target)
# t = (t - np.mean(t)) / np.std(t)

# %%
K.clear_session()

inputs1 = layers.Input(shape= (train_X.shape[1], ))
inputs2 = layers.Input(shape = (tr_km.shape[1], ))

x1 = layers.Dense(32, kernel_initializer='he_normal')(inputs1)
x1 = layers.advanced_activations.LeakyReLU(0.1)(x1)
# x1 = layers.Dense(32, kernel_initializer='he_normal')(x1)
# x1 = layers.advanced_activations.LeakyReLU(0.1)(x1)

x2 = layers.Dense(32, kernel_initializer='he_normal')(inputs2)
x2 = layers.advanced_activations.LeakyReLU(0.1)(x2)

x = layers.Concatenate()([x1, x2])

x = layers.Dense(16, kernel_initializer='he_normal')(x)
x1 = layers.advanced_activations.LeakyReLU(0.3)(x1)

outputs = layers.Dense(1, activation = 'linear', kernel_initializer='he_normal')(x)

nn = models.Model([inputs1, inputs2], outputs)

nn.compile(optimizer = optimizers.Adam(),
          loss = Huber(),
          metrics = ['mae'])

# %%
nn.fit([train_X.values, tr_km], t.values,
      epochs=100,
      validation_split=0.3,
      callbacks=[es])
# Out:
# Train on 6252 samples, validate on 2680 samples
# Epoch 1/100
# 6252/6252 [==============================] - 1s 150us/step - loss: 2.8363 - mae: 3.2805 - val_loss: 1.0276 - val_mae: 1.4471
# Epoch 2/100
# 6252/6252 [==============================] - 1s 119us/step - loss: 0.4788 - mae: 0.8566 - val_loss: 0.7049 - val_mae: 1.1401
# Epoch 3/100
# 6252/6252 [==============================] - 1s 121us/step - loss: 0.3239 - mae: 0.6773 - val_loss: 0.6567 - val_mae: 1.0989
# Epoch 4/100
# 6252/6252 [==============================] - 1s 120us/step - loss: 0.2778 - mae: 0.6195 - val_loss: 0.4319 - val_mae: 0.8258
# Epoch 5/100
# 6252/6252 [==============================] - 1s 119us/step - loss: 0.2428 - mae: 0.5750 - val_loss: 0.3938 - val_mae: 0.7841
# Epoch 6/100
# 6252/6252 [==============================] - 1s 119us/step - loss: 0.2166 - mae: 0.5387 - val_loss: 0.5350 - val_mae: 0.9808
# Epoch 7/100
# 6252/6252 [==============================] - 1s 122us/step - loss: 0.1847 - mae: 0.4955 - val_loss: 0.3231 - val_mae: 0.7086
# Epoch 8/100
# 6252/6252 [==============================] - 1s 119us/step - loss: 0.1565 - mae: 0.4541 - val_loss: 0.2260 - val_mae: 0.5775
# Epoch 9/100
# 6252/6252 [==============================] - 1s 124us/step - loss: 0.1343 - mae: 0.4188 - val_loss: 0.0999 - val_mae: 0.3437
# Epoch 10/100
# 6252/6252 [==============================] - 1s 121us/step - loss: 0.1070 - mae: 0.3739 - val_loss: 0.1645 - val_mae: 0.4946
# Epoch 11/100
# 6252/6252 [==============================] - 1s 123us/step - loss: 0.0878 - mae: 0.3392 - val_loss: 0.1472 - val_mae: 0.4578
# Epoch 12/100
# 6252/6252 [==============================] - 1s 122us/step - loss: 0.0711 - mae: 0.3026 - val_loss: 0.0729 - val_mae: 0.2828
# Epoch 13/100
# 6252/6252 [==============================] - 1s 121us/step - loss: 0.0606 - mae: 0.2776 - val_loss: 0.0653 - val_mae: 0.2604
# Epoch 14/100
# 6252/6252 [==============================] - 1s 118us/step - loss: 0.0524 - mae: 0.2566 - val_loss: 0.0482 - val_mae: 0.2155
# Epoch 15/100
# 6252/6252 [==============================] - 1s 122us/step - loss: 0.0485 - mae: 0.2457 - val_loss: 0.0693 - val_mae: 0.2920
# Epoch 16/100
# 6252/6252 [==============================] - 1s 120us/step - loss: 0.0438 - mae: 0.2328 - val_loss: 0.0586 - val_mae: 0.2425
# Epoch 17/100
# 6252/6252 [==============================] - 1s 125us/step - loss: 0.0396 - mae: 0.2195 - val_loss: 0.0402 - val_mae: 0.2173
# Epoch 18/100
# 6252/6252 [==============================] - 1s 123us/step - loss: 0.0381 - mae: 0.2160 - val_loss: 0.0337 - val_mae: 0.1936
# Epoch 19/100
# 6252/6252 [==============================] - 1s 120us/step - loss: 0.0360 - mae: 0.2087 - val_loss: 0.0317 - val_mae: 0.1799
# Epoch 20/100
# 6252/6252 [==============================] - 1s 119us/step - loss: 0.0339 - mae: 0.2032 - val_loss: 0.0459 - val_mae: 0.2339
# Epoch 21/100
# 6252/6252 [==============================] - 1s 116us/step - loss: 0.0323 - mae: 0.1968 - val_loss: 0.0356 - val_mae: 0.1979
# Epoch 22/100
# 6252/6252 [==============================] - 1s 118us/step - loss: 0.0316 - mae: 0.1956 - val_loss: 0.0335 - val_mae: 0.1898
# Epoch 23/100
# 6252/6252 [==============================] - 1s 118us/step - loss: 0.0298 - mae: 0.1881 - val_loss: 0.0405 - val_mae: 0.2154
# Epoch 24/100
# 6252/6252 [==============================] - 1s 124us/step - loss: 0.0295 - mae: 0.1878 - val_loss: 0.0593 - val_mae: 0.2730
# Epoch 25/100
# 6252/6252 [==============================] - 1s 118us/step - loss: 0.0300 - mae: 0.1905 - val_loss: 0.0579 - val_mae: 0.2720
# Epoch 26/100
# 6252/6252 [==============================] - 1s 129us/step - loss: 0.0287 - mae: 0.1857 - val_loss: 0.0731 - val_mae: 0.3172
# Epoch 27/100
# 6252/6252 [==============================] - 1s 123us/step - loss: 0.0286 - mae: 0.1847 - val_loss: 0.0422 - val_mae: 0.2185
# Epoch 28/100
# 6252/6252 [==============================] - 1s 123us/step - loss: 0.0297 - mae: 0.1896 - val_loss: 0.0553 - val_mae: 0.2700
# Epoch 29/100
# 6252/6252 [==============================] - 1s 119us/step - loss: 0.0266 - mae: 0.1778 - val_loss: 0.0864 - val_mae: 0.3508

# %%
sub['value'] = np.exp(nn.predict([test_X.values, te_km]))
print(sub)
# Out:
#          id         value
# 0         1  2.546610e+08
# 1         2  2.671213e+08
# 2         4  1.718574e+08
# 3         5  1.762082e+08
# 4         6  7.684925e+07
# ...     ...           ...
# 3823  16924  2.438191e+04
# 3824  16929  1.766639e+05
# 3825  16932  3.377254e+04
# 3826  16937  2.598425e+04
# 3827  16943  2.304784e+04
#
# [3828 rows x 2 columns]

# %%
sub.to_csv('./sub/pre/km_nn6.csv', index=False)

# %%
new_tr_X.shape

# %%
K.clear_session()

nn = models.Sequential()
nn.add(layers.Dense(32, kernel_regularizer=L1L2(l2=0.001)))
nn.add(layers.advanced_activations.LeakyReLU(0.1))
nn.add(layers.Dropout(0.3))
# nn.add(layers.Dense(32, kernel_regularizer=L1L2(l2=0.001)))
# nn.add(layers.advanced_activations.LeakyReLU(0.1))

nn.add(layers.Dense(1, activation='linear'))

nn.compile(optimizer = optimizers.Adam(lr=1e-4),
          loss = 'mse',
          metrics = ['mae'])

# %%
nn.fit(new_tr_X, target.values,
      epochs=50,
      validation_split=0.3,
      callbacks = [es])

# %%
sub['value'] = nn.predict(new_te_X)
print(sub)

# %%
sub.to_csv('./sub/pre/nn2.csv', index=False)

# %%
new_te_X
